# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import mean_squared_error, r2_score

# Load the TSV file
df = pd.read_csv('ml-32m/ratings.csv')


# Print the head of the DataFrame
print(df.head())
# Out:
# /Users/alexanderaujesky/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2024-11-15 10:33:03.638792: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
data_folder = './MovieSummaries/MovieSummaries/'
#paths to files
plot_summaries_path = data_folder + 'plot_summaries.txt'
movie_metadata_path = data_folder + 'movie.metadata.tsv'
character_metadata_path = data_folder + 'character.metadata.tsv'

# load the data
# 1. Plot summaries data
plot_summaries_df = pd.read_csv(plot_summaries_path, delimiter='\t', names=['wikipedia_movie_id', 'plot_summary'], 
                                 encoding='utf-8')

# 2. Movie metadata
movie_metadata_df = pd.read_csv(movie_metadata_path, delimiter='\t', names=['wikipedia_movie_id', 'freebase_movie_id', 
                                                                            'movie_name', 'release_date', 'box_office_revenue',
                                                                            'runtime', 'languages', 'countries', 'genres'], 
                                 encoding='utf-8')

# 3. Character metadata
character_metadata_df = pd.read_csv(character_metadata_path, delimiter='\t', names=['wikipedia_movie_id', 'freebase_movie_id', 'release_date', 'character_name', 
                                                                                    'actor_dob', 'actor_gender', 'actor_height', 'actor_ethnicity', 'actor_name', 
                                                                                    'actor_age_at_release', 'freebase_character_actor_map_id', 'freebase_character_id', 
                                                                                    'freebase_actor_id'], 
                                     encoding='utf-8')

# %%
movies = pd.read_csv('ml-32m/movies.csv')

# %%
movie_metadata_df['movie_name_formatted'] = movie_metadata_df['movie_name'].str.lower().str.strip()
movies['title_format'] = movies['title'].str[:-6].str.strip().str.lower()

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres                 title_format
# 0  Adventure|Animation|Children|Comedy|Fantasy                    toy story
# 1                   Adventure|Children|Fantasy                      jumanji
# 2                               Comedy|Romance             grumpier old men
# 3                         Comedy|Drama|Romance            waiting to exhale
# 4                                       Comedy  father of the bride part ii

# %%
# calculate the number of common movies between the two datasets

common_movies = set(movie_metadata_df['movie_name_formatted']).intersection(set(movies['title_format']))
print('Number of common movies:', len(common_movies))

# merge the two datasets

merged_df = pd.merge(movies, movie_metadata_df, left_on='title_format', right_on='movie_name_formatted', how='inner')
# Out:
# Number of common movies: 12318

# %%
merged_df
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 17557   131152                  The Fat Spy (1966)
# 17558   131166                   WWII IN HD (2009)
# 17559   131239           Three Quarter Moon (2011)
# 17560   131248               Brother Bear 2 (2006)
# 17561   131260                 Rentun Ruusu (2001)
#
#                                           genres_x  \
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 17557                                       Comedy
# 17558                           (no genres listed)
# 17559                                 Comedy|Drama
# 17560  Adventure|Animation|Children|Comedy|Fantasy
# 17561                           (no genres listed)
#
#                       title_format  wikipedia_movie_id freebase_movie_id  \
# 0                        toy story               53085          /m/0dyb1
# 1                          jumanji             3700174         /m/09w353
# 2                 grumpier old men             1934035         /m/0676dr
# 3                waiting to exhale              972970         /m/03vny7
# 4      father of the bride part ii             3303622         /m/094g2z
# ...                            ...                 ...               ...
# 17557                  the fat spy             1853200         /m/0613sx
# 17558                   wwii in hd            26321497        /m/0bbxzy2
# 17559           three quarter moon            33597212        /m/0hgrd5g
# 17560               brother bear 2             4118248         /m/0bk2k2
# 17561                 rentun ruusu            10166655        /m/02q3_cx
#
#                         movie_name release_date  box_office_revenue  runtime  \
# 0                        Toy Story   1995-11-19         361958736.0     77.0
# 1                          Jumanji   1995-12-15         262797249.0    104.0
# 2                 Grumpier Old Men   1995-12-22          71518503.0    101.0
# 3                Waiting to Exhale   1995-12-22          81452156.0    121.0
# 4      Father of the Bride Part II   1995-12-08          76594107.0    106.0
# ...                            ...          ...                 ...      ...
# 17557                  The Fat Spy         1966                 NaN     75.0
# 17558                   WWII in HD          NaN                 NaN      NaN
# 17559           Three Quarter Moon   2011-09-30                 NaN     95.0
# 17560               Brother Bear 2   2006-08-29                 NaN     73.0
# 17561                 Rentun Ruusu   2001-01-12                 NaN    100.0
#
#                                                languages  \
# 0                     {"/m/02h40lc": "English Language"}
# 1      {"/m/064_8sq": "French Language", "/m/02h40lc"...
# 2      {"/m/02bjrlw": "Italian Language", "/m/02h40lc...
# 3                     {"/m/02h40lc": "English Language"}
# 4                     {"/m/02h40lc": "English Language"}
# ...                                                  ...
# 17557                 {"/m/02h40lc": "English Language"}
# 17558                                                 {}
# 17559  {"/m/02hwyss": "Turkish Language", "/m/0gtg": ...
# 17560                 {"/m/02h40lc": "English Language"}
# 17561                  {"/m/01gp_d": "Finnish Language"}
#
#                                                countries  \
# 0              {"/m/09c7w0": "United States of America"}
# 1      {"/m/09c7w0": "United States of America", "/m/...
# 2              {"/m/09c7w0": "United States of America"}
# 3              {"/m/09c7w0": "United States of America"}
# 4              {"/m/09c7w0": "United States of America"}
# ...                                                  ...
# 17557          {"/m/09c7w0": "United States of America"}
# 17558                                                 {}
# 17559                            {"/m/0345h": "Germany"}
# 17560          {"/m/09c7w0": "United States of America"}
# 17561                            {"/m/02vzc": "Finland"}
#
#                                                 genres_y  \
# 0      {"/m/0556j8": "Buddy film", "/m/03k9fj": "Adve...
# 1      {"/m/01jfsb": "Thriller", "/m/0hj3n2k": "Fanta...
# 2      {"/m/06cvj": "Romantic comedy", "/m/0556j8": "...
# 3      {"/m/0hj3n0w": "Ensemble Film", "/m/06w2n3t": ...
# 4      {"/m/06qm3": "Screwball comedy", "/m/02l7c8": ...
# ...                                                  ...
# 17557  {"/m/0gf28": "Parody", "/m/0220p9g": "Musical ...
# 17558                           {"/m/082gq": "War film"}
# 17559  {"/m/0556j8": "Buddy film", "/m/0hqxf": "Famil...
# 17560  {"/m/0hqxf": "Family Film", "/m/0hcr": "Animat...
# 17561                 {"/m/03bxz7": "Biographical film"}
#
#               movie_name_formatted
# 0                        toy story
# 1                          jumanji
# 2                 grumpier old men
# 3                waiting to exhale
# 4      father of the bride part ii
# ...                            ...
# 17557                  the fat spy
# 17558                   wwii in hd
# 17559           three quarter moon
# 17560               brother bear 2
# 17561                 rentun ruusu
#
# [17562 rows x 14 columns]

# %%
# Remove this user from the dataset, because it has too many ratings
df = df[df['userId'] != 175325]

# %%
list_of_genres=movies['genres'].unique()

# %%
# Print the user with the most ratings
user_ratings_count = df['userId'].value_counts()

print('User with the most ratings:')
print(user_ratings_count.head(20))
# Out:
# User with the most ratings:
# 118205    9254
# 8405      7515
# 82418     5646
# 121535    5520
# 125794    5491
# 74142     5447
# 34576     5356
# 131904    5330
# 83090     5169
# 59477     4988
# 130767    4785
# 79159     4707
# 8963      4524
# 15617     4354
# 92011     4236
# 71975     4182
# 20132     4101
# 46470     4094
# 88820     4093
# 63147     3958
# Name: userId, dtype: int64

# %%
rating_films=pd.merge(movies,df,on='movieId',how='inner')

# %%
unique_genres = movies['genres'].unique()
all_genres = set('|'.join(unique_genres).split('|'))

all_genres_list = list(all_genres)
all_genres_list.remove('(no genres listed)')
print(all_genres_list)
# Out:
# ['Thriller', 'Film-Noir', 'War', 'Animation', 'IMAX', 'Fantasy', 'Drama', 'Mystery', 'Horror', 'Sci-Fi', 'Adventure', 'Western', 'Children', 'Comedy', 'Romance', 'Crime', 'Musical', 'Action', 'Documentary']

# %%
# Create a one hot encoding for each genre
for genre in all_genres_list : 
    rating_films[genre] = rating_films['genres'].apply(lambda x: genre in x.split('|'))
rating_films
# Out:
#           movieId                          title  \
# 0               1               Toy Story (1995)
# 1               1               Toy Story (1995)
# 2               1               Toy Story (1995)
# 3               1               Toy Story (1995)
# 4               1               Toy Story (1995)
# ...           ...                            ...
# 20000258   131254   Kein Bund für's Leben (2007)
# 20000259   131256  Feuer, Eis & Dosenbier (2002)
# 20000260   131258             The Pirates (2014)
# 20000261   131260            Rentun Ruusu (2001)
# 20000262   131262               Innocence (2014)
#
#                                                genres            title_format  \
# 0         Adventure|Animation|Children|Comedy|Fantasy               toy story
# 1         Adventure|Animation|Children|Comedy|Fantasy               toy story
# 2         Adventure|Animation|Children|Comedy|Fantasy               toy story
# 3         Adventure|Animation|Children|Comedy|Fantasy               toy story
# 4         Adventure|Animation|Children|Comedy|Fantasy               toy story
# ...                                               ...                     ...
# 20000258                                       Comedy   kein bund für's leben
# 20000259                                       Comedy  feuer, eis & dosenbier
# 20000260                                    Adventure             the pirates
# 20000261                           (no genres listed)            rentun ruusu
# 20000262                     Adventure|Fantasy|Horror               innocence
#
#           userId  rating            timestamp  Thriller  Film-Noir    War  \
# 0              3     4.0  1999-12-11 13:36:47     False      False  False
# 1              6     5.0  1997-03-13 17:50:52     False      False  False
# 2              8     4.0  1996-06-05 13:37:51     False      False  False
# 3             10     4.0  1999-11-25 02:44:47     False      False  False
# 4             11     4.5  2009-01-02 01:13:41     False      False  False
# ...          ...     ...                  ...       ...        ...    ...
# 20000258   79570     4.0  2015-03-30 19:32:59     False      False  False
# 20000259   79570     4.0  2015-03-30 19:48:08     False      False  False
# 20000260   28906     2.5  2015-03-30 19:56:32     False      False  False
# 20000261   65409     3.0  2015-03-30 19:57:46     False      False  False
# 20000262  133047     4.0  2015-03-30 20:39:26     False      False  False
#
#           ...  Sci-Fi  Adventure  Western  Children  Comedy  Romance  Crime  \
# 0         ...   False       True    False      True    True    False  False
# 1         ...   False       True    False      True    True    False  False
# 2         ...   False       True    False      True    True    False  False
# 3         ...   False       True    False      True    True    False  False
# 4         ...   False       True    False      True    True    False  False
# ...       ...     ...        ...      ...       ...     ...      ...    ...
# 20000258  ...   False      False    False     False    True    False  False
# 20000259  ...   False      False    False     False    True    False  False
# 20000260  ...   False       True    False     False   False    False  False
# 20000261  ...   False      False    False     False   False    False  False
# 20000262  ...   False       True    False     False   False    False  False
#
#           Musical  Action  Documentary
# 0           False   False        False
# 1           False   False        False
# 2           False   False        False
# 3           False   False        False
# 4           False   False        False
# ...           ...     ...          ...
# 20000258    False   False        False
# 20000259    False   False        False
# 20000260    False   False        False
# 20000261    False   False        False
# 20000262    False   False        False
#
# [20000263 rows x 26 columns]

# %%
def rating_for_userID_generator(userId):
    user_rating = rating_films[rating_films['userId'] == userId]
    user_rating = user_rating.iloc[:, 5:].sample(frac=1)  
    user_rating = user_rating.drop(columns=['timestamp'])
    y = user_rating['rating']
    x = user_rating.drop(columns=['rating'])
    
    length = len(y)
    x_size = int(length * 0.8) 
    
    x_train = x.iloc[:x_size, :]
    x_test = x.iloc[x_size:, :]
    y_train = y.iloc[:x_size]
    y_test = y.iloc[x_size:]
    
    return x_train, y_train, x_test, y_test

x_train, y_train, x_test, y_test = rating_for_userID_generator(8405)

# %%
# Define the neural network model
model = Sequential([
    Dense(64, input_dim=x_train.shape[1], activation='relu'),  # First hidden layer
    Dense(32, activation='relu'),  # Second hidden layer
    Dense(1, activation='linear')  # Output layer for regression
])

# Compile the model
model.compile(optimizer='adam', loss='mse', metrics=['mse'])

# Train the model
history = model.fit(x_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)

# Predict on both training and test sets
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

# Evaluate the model
train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

print("Training Set Evaluation:")
print("MSE:", train_mse)
print("R^2 Score:", train_r2)

print("\nTest Set Evaluation:")
print("MSE:", test_mse)
print("R^2 Score:", test_r2)
# Out:
# Epoch 1/100
# 151/151 [==============================] - 1s 4ms/step - loss: 2.7784 - mse: 2.7784 - val_loss: 0.9295 - val_mse: 0.9295
# Epoch 2/100
# 151/151 [==============================] - 1s 3ms/step - loss: 0.8512 - mse: 0.8512 - val_loss: 0.8112 - val_mse: 0.8112
# Epoch 3/100
# 151/151 [==============================] - 1s 3ms/step - loss: 0.7950 - mse: 0.7950 - val_loss: 0.7861 - val_mse: 0.7861
# Epoch 4/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7792 - mse: 0.7792 - val_loss: 0.7809 - val_mse: 0.7809
# Epoch 5/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7737 - mse: 0.7737 - val_loss: 0.7802 - val_mse: 0.7802
# Epoch 6/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7698 - mse: 0.7698 - val_loss: 0.7821 - val_mse: 0.7821
# Epoch 7/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7635 - mse: 0.7635 - val_loss: 0.7769 - val_mse: 0.7769
# Epoch 8/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7625 - mse: 0.7625 - val_loss: 0.7836 - val_mse: 0.7836
# Epoch 9/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7594 - mse: 0.7594 - val_loss: 0.7773 - val_mse: 0.7773
# Epoch 10/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7572 - mse: 0.7572 - val_loss: 0.7799 - val_mse: 0.7799
# Epoch 11/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7537 - mse: 0.7537 - val_loss: 0.7826 - val_mse: 0.7826
# Epoch 12/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7513 - mse: 0.7513 - val_loss: 0.7783 - val_mse: 0.7783
# Epoch 13/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7524 - mse: 0.7524 - val_loss: 0.7896 - val_mse: 0.7896
# Epoch 14/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7498 - mse: 0.7498 - val_loss: 0.7918 - val_mse: 0.7918
# Epoch 15/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7538 - mse: 0.7538 - val_loss: 0.7778 - val_mse: 0.7778
# Epoch 16/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7512 - mse: 0.7512 - val_loss: 0.7890 - val_mse: 0.7890
# Epoch 17/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7456 - mse: 0.7456 - val_loss: 0.7829 - val_mse: 0.7829
# Epoch 18/100
# 151/151 [==============================] - 1s 3ms/step - loss: 0.7472 - mse: 0.7472 - val_loss: 0.7849 - val_mse: 0.7849
# Epoch 19/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7442 - mse: 0.7442 - val_loss: 0.7933 - val_mse: 0.7933
# Epoch 20/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7451 - mse: 0.7451 - val_loss: 0.7879 - val_mse: 0.7879
# Epoch 21/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7428 - mse: 0.7428 - val_loss: 0.7915 - val_mse: 0.7915
# Epoch 22/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7382 - mse: 0.7382 - val_loss: 0.7885 - val_mse: 0.7885
# Epoch 23/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7402 - mse: 0.7402 - val_loss: 0.7959 - val_mse: 0.7959
# Epoch 24/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7375 - mse: 0.7375 - val_loss: 0.8078 - val_mse: 0.8078
# Epoch 25/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7379 - mse: 0.7379 - val_loss: 0.8218 - val_mse: 0.8218
# Epoch 26/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7331 - mse: 0.7331 - val_loss: 0.7913 - val_mse: 0.7913
# Epoch 27/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7339 - mse: 0.7339 - val_loss: 0.7909 - val_mse: 0.7909
# Epoch 28/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7321 - mse: 0.7321 - val_loss: 0.8004 - val_mse: 0.8004
# Epoch 29/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7313 - mse: 0.7313 - val_loss: 0.7956 - val_mse: 0.7956
# Epoch 30/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7310 - mse: 0.7310 - val_loss: 0.8010 - val_mse: 0.8010
# Epoch 31/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7298 - mse: 0.7298 - val_loss: 0.7921 - val_mse: 0.7921
# Epoch 32/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7318 - mse: 0.7318 - val_loss: 0.7991 - val_mse: 0.7991
# Epoch 33/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7293 - mse: 0.7293 - val_loss: 0.7948 - val_mse: 0.7948
# Epoch 34/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7312 - mse: 0.7312 - val_loss: 0.8044 - val_mse: 0.8044
# Epoch 35/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7291 - mse: 0.7291 - val_loss: 0.8194 - val_mse: 0.8194
# Epoch 36/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7245 - mse: 0.7245 - val_loss: 0.8027 - val_mse: 0.8027
# Epoch 37/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7258 - mse: 0.7258 - val_loss: 0.8057 - val_mse: 0.8057
# Epoch 38/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7210 - mse: 0.7210 - val_loss: 0.8079 - val_mse: 0.8079
# Epoch 39/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7222 - mse: 0.7222 - val_loss: 0.8041 - val_mse: 0.8041
# Epoch 40/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7250 - mse: 0.7250 - val_loss: 0.8126 - val_mse: 0.8126
# Epoch 41/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7235 - mse: 0.7235 - val_loss: 0.8124 - val_mse: 0.8124
# Epoch 42/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7218 - mse: 0.7218 - val_loss: 0.8219 - val_mse: 0.8219
# Epoch 43/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7199 - mse: 0.7199 - val_loss: 0.8214 - val_mse: 0.8214
# Epoch 44/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7189 - mse: 0.7189 - val_loss: 0.8023 - val_mse: 0.8023
# Epoch 45/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7197 - mse: 0.7197 - val_loss: 0.8133 - val_mse: 0.8133
# Epoch 46/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7216 - mse: 0.7216 - val_loss: 0.8063 - val_mse: 0.8063
# Epoch 47/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7210 - mse: 0.7210 - val_loss: 0.8090 - val_mse: 0.8090
# Epoch 48/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7203 - mse: 0.7203 - val_loss: 0.8093 - val_mse: 0.8093
# Epoch 49/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7163 - mse: 0.7163 - val_loss: 0.8115 - val_mse: 0.8115
# Epoch 50/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7166 - mse: 0.7166 - val_loss: 0.8176 - val_mse: 0.8176
# Epoch 51/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7150 - mse: 0.7150 - val_loss: 0.8183 - val_mse: 0.8183
# Epoch 52/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7168 - mse: 0.7168 - val_loss: 0.8205 - val_mse: 0.8205
# Epoch 53/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7138 - mse: 0.7138 - val_loss: 0.8249 - val_mse: 0.8249
# Epoch 54/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7179 - mse: 0.7179 - val_loss: 0.8161 - val_mse: 0.8161
# Epoch 55/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7131 - mse: 0.7131 - val_loss: 0.8200 - val_mse: 0.8200
# Epoch 56/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7172 - mse: 0.7172 - val_loss: 0.8210 - val_mse: 0.8210
# Epoch 57/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7129 - mse: 0.7129 - val_loss: 0.8197 - val_mse: 0.8197
# Epoch 58/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7148 - mse: 0.7148 - val_loss: 0.8211 - val_mse: 0.8211
# Epoch 59/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7148 - mse: 0.7148 - val_loss: 0.8239 - val_mse: 0.8239
# Epoch 60/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7089 - mse: 0.7089 - val_loss: 0.8161 - val_mse: 0.8161
# Epoch 61/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7143 - mse: 0.7143 - val_loss: 0.8222 - val_mse: 0.8222
# Epoch 62/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7111 - mse: 0.7111 - val_loss: 0.8181 - val_mse: 0.8181
# Epoch 63/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7122 - mse: 0.7122 - val_loss: 0.8154 - val_mse: 0.8154
# Epoch 64/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7152 - mse: 0.7152 - val_loss: 0.8288 - val_mse: 0.8288
# Epoch 65/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7108 - mse: 0.7108 - val_loss: 0.8259 - val_mse: 0.8259
# Epoch 66/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7094 - mse: 0.7094 - val_loss: 0.8211 - val_mse: 0.8211
# Epoch 67/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7076 - mse: 0.7076 - val_loss: 0.8170 - val_mse: 0.8170
# Epoch 68/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7102 - mse: 0.7102 - val_loss: 0.8315 - val_mse: 0.8315
# Epoch 69/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7117 - mse: 0.7117 - val_loss: 0.8208 - val_mse: 0.8208
# Epoch 70/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7062 - mse: 0.7062 - val_loss: 0.8345 - val_mse: 0.8345
# Epoch 71/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7054 - mse: 0.7054 - val_loss: 0.8283 - val_mse: 0.8283
# Epoch 72/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7059 - mse: 0.7059 - val_loss: 0.8361 - val_mse: 0.8361
# Epoch 73/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7096 - mse: 0.7096 - val_loss: 0.8546 - val_mse: 0.8546
# Epoch 74/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7084 - mse: 0.7084 - val_loss: 0.8330 - val_mse: 0.8330
# Epoch 75/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7049 - mse: 0.7049 - val_loss: 0.8259 - val_mse: 0.8259
# Epoch 76/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7107 - mse: 0.7107 - val_loss: 0.8600 - val_mse: 0.8600
# Epoch 77/100
# 151/151 [==============================] - 1s 4ms/step - loss: 0.7068 - mse: 0.7068 - val_loss: 0.8310 - val_mse: 0.8310
# Epoch 78/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7058 - mse: 0.7058 - val_loss: 0.8548 - val_mse: 0.8548
# Epoch 79/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7063 - mse: 0.7063 - val_loss: 0.8225 - val_mse: 0.8225
# Epoch 80/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7059 - mse: 0.7059 - val_loss: 0.8348 - val_mse: 0.8348
# Epoch 81/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7039 - mse: 0.7039 - val_loss: 0.8261 - val_mse: 0.8261
# Epoch 82/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7052 - mse: 0.7052 - val_loss: 0.8282 - val_mse: 0.8282
# Epoch 83/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7064 - mse: 0.7064 - val_loss: 0.8460 - val_mse: 0.8460
# Epoch 84/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7046 - mse: 0.7046 - val_loss: 0.8271 - val_mse: 0.8271
# Epoch 85/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7008 - mse: 0.7008 - val_loss: 0.8283 - val_mse: 0.8283
# Epoch 86/100
# 151/151 [==============================] - 1s 4ms/step - loss: 0.7019 - mse: 0.7019 - val_loss: 0.8384 - val_mse: 0.8384
# Epoch 87/100
# 151/151 [==============================] - 1s 4ms/step - loss: 0.7015 - mse: 0.7015 - val_loss: 0.8259 - val_mse: 0.8259
# Epoch 88/100
# 151/151 [==============================] - 1s 4ms/step - loss: 0.7030 - mse: 0.7030 - val_loss: 0.8324 - val_mse: 0.8324
# Epoch 89/100
# 151/151 [==============================] - 1s 3ms/step - loss: 0.7006 - mse: 0.7006 - val_loss: 0.8358 - val_mse: 0.8358
# Epoch 90/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7028 - mse: 0.7028 - val_loss: 0.8420 - val_mse: 0.8420
# Epoch 91/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7009 - mse: 0.7009 - val_loss: 0.8346 - val_mse: 0.8346
# Epoch 92/100
# 151/151 [==============================] - 1s 3ms/step - loss: 0.6995 - mse: 0.6995 - val_loss: 0.8400 - val_mse: 0.8400
# Epoch 93/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7006 - mse: 0.7006 - val_loss: 0.8357 - val_mse: 0.8357
# Epoch 94/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.6985 - mse: 0.6985 - val_loss: 0.8312 - val_mse: 0.8312
# Epoch 95/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.6978 - mse: 0.6978 - val_loss: 0.8382 - val_mse: 0.8382
# Epoch 96/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7019 - mse: 0.7019 - val_loss: 0.8312 - val_mse: 0.8312
# Epoch 97/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7011 - mse: 0.7011 - val_loss: 0.8346 - val_mse: 0.8346
# Epoch 98/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.6995 - mse: 0.6995 - val_loss: 0.8392 - val_mse: 0.8392
# Epoch 99/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7006 - mse: 0.7006 - val_loss: 0.8344 - val_mse: 0.8344
# Epoch 100/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.6968 - mse: 0.6968 - val_loss: 0.8361 - val_mse: 0.8361
# 188/188 [==============================] - 0s 1ms/step
# 47/47 [==============================] - 0s 1ms/step
# Training Set Evaluation:
# MSE: 0.7135764419009808
# R^2 Score: 0.21454117065296352
#
# Test Set Evaluation:
# MSE: 0.7720133287692126
# R^2 Score: 0.10851401569079355

# %%
def evaluate_model_for_user(userId, data):
    """
    Generates training and test splits for a given user ID, trains a neural network, 
    and evaluates the model to return MSE and R^2 for both training and test sets.
    """
    # Filter and preprocess data for the given user
    user_rating = data[data['userId'] == userId]
    user_rating = user_rating.iloc[:, 5:].sample(frac=1)  # Shuffle data
    user_rating = user_rating.drop(columns=['timestamp'])
    y = user_rating['rating']
    x = user_rating.drop(columns=['rating'])

    # Split into training and testing sets
    length = len(y)
    x_size = int(length * 0.8)
    x_train, x_test = x.iloc[:x_size, :], x.iloc[x_size:, :]
    y_train, y_test = y.iloc[:x_size], y.iloc[x_size:]

    # Define the neural network model
    model = Sequential([
        Dense(64, input_dim=x_train.shape[1], activation='relu'),  # First hidden layer
        Dense(32, activation='relu'),  # Second hidden layer
        Dense(1, activation='linear')  # Output layer for regression
    ])

    # Compile the model
    model.compile(optimizer='adam', loss='mse', metrics=['mse'])

    # Train the model
    model.fit(x_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)

    # Predict on training and test sets
    y_train_pred = model.predict(x_train)
    y_test_pred = model.predict(x_test)

    # Calculate evaluation metrics
    train_mse = mean_squared_error(y_train, y_train_pred)
    test_mse = mean_squared_error(y_test, y_test_pred)
    train_r2 = r2_score(y_train, y_train_pred)
    test_r2 = r2_score(y_test, y_test_pred)

    # Print evaluation results
    print(f"Evaluation for User ID {userId}:")
    print("Training Set Evaluation:")
    print(f"MSE: {train_mse:.4f}, R^2: {train_r2:.4f}")
    print("\nTest Set Evaluation:")
    print(f"MSE: {test_mse:.4f}, R^2: {test_r2:.4f}")

    # Return MSE values for both sets
    return train_mse, test_mse

train_mse, test_mse = evaluate_model_for_user(8405, rating_films)
# Out:
# Epoch 1/100
# 151/151 [==============================] - 1s 3ms/step - loss: 3.3125 - mse: 3.3125 - val_loss: 0.8634 - val_mse: 0.8634
# Epoch 2/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.8529 - mse: 0.8529 - val_loss: 0.7774 - val_mse: 0.7774
# Epoch 3/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7978 - mse: 0.7978 - val_loss: 0.7391 - val_mse: 0.7391
# Epoch 4/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7780 - mse: 0.7780 - val_loss: 0.7344 - val_mse: 0.7344
# Epoch 5/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7735 - mse: 0.7735 - val_loss: 0.7257 - val_mse: 0.7257
# Epoch 6/100
# 151/151 [==============================] - 1s 5ms/step - loss: 0.7646 - mse: 0.7646 - val_loss: 0.7233 - val_mse: 0.7233
# Epoch 7/100
# 151/151 [==============================] - 1s 3ms/step - loss: 0.7606 - mse: 0.7606 - val_loss: 0.7376 - val_mse: 0.7376
# Epoch 8/100
# 151/151 [==============================] - 1s 6ms/step - loss: 0.7587 - mse: 0.7587 - val_loss: 0.7396 - val_mse: 0.7396
# Epoch 9/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7568 - mse: 0.7568 - val_loss: 0.7272 - val_mse: 0.7272
# Epoch 10/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7589 - mse: 0.7589 - val_loss: 0.7283 - val_mse: 0.7283
# Epoch 11/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7560 - mse: 0.7560 - val_loss: 0.7233 - val_mse: 0.7233
# Epoch 12/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7521 - mse: 0.7521 - val_loss: 0.7467 - val_mse: 0.7467
# Epoch 13/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7500 - mse: 0.7500 - val_loss: 0.7346 - val_mse: 0.7346
# Epoch 14/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7493 - mse: 0.7493 - val_loss: 0.7475 - val_mse: 0.7475
# Epoch 15/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7478 - mse: 0.7478 - val_loss: 0.7324 - val_mse: 0.7324
# Epoch 16/100
# 151/151 [==============================] - 1s 3ms/step - loss: 0.7451 - mse: 0.7451 - val_loss: 0.7316 - val_mse: 0.7316
# Epoch 17/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7467 - mse: 0.7467 - val_loss: 0.7234 - val_mse: 0.7234
# Epoch 18/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7457 - mse: 0.7457 - val_loss: 0.7291 - val_mse: 0.7291
# Epoch 19/100
# 151/151 [==============================] - 1s 4ms/step - loss: 0.7469 - mse: 0.7469 - val_loss: 0.7279 - val_mse: 0.7279
# Epoch 20/100
# 151/151 [==============================] - 1s 3ms/step - loss: 0.7409 - mse: 0.7409 - val_loss: 0.7291 - val_mse: 0.7291
# Epoch 21/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7424 - mse: 0.7424 - val_loss: 0.7540 - val_mse: 0.7540
# Epoch 22/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7422 - mse: 0.7422 - val_loss: 0.7768 - val_mse: 0.7768
# Epoch 23/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7423 - mse: 0.7423 - val_loss: 0.7308 - val_mse: 0.7308
# Epoch 24/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7399 - mse: 0.7399 - val_loss: 0.7259 - val_mse: 0.7259
# Epoch 25/100
# 151/151 [==============================] - 1s 4ms/step - loss: 0.7387 - mse: 0.7387 - val_loss: 0.7314 - val_mse: 0.7314
# Epoch 26/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7373 - mse: 0.7373 - val_loss: 0.7314 - val_mse: 0.7314
# Epoch 27/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7405 - mse: 0.7405 - val_loss: 0.7321 - val_mse: 0.7321
# Epoch 28/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7356 - mse: 0.7356 - val_loss: 0.7310 - val_mse: 0.7310
# Epoch 29/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7389 - mse: 0.7389 - val_loss: 0.7360 - val_mse: 0.7360
# Epoch 30/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7356 - mse: 0.7356 - val_loss: 0.7311 - val_mse: 0.7311
# Epoch 31/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7357 - mse: 0.7357 - val_loss: 0.7331 - val_mse: 0.7331
# Epoch 32/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7334 - mse: 0.7334 - val_loss: 0.7298 - val_mse: 0.7298
# Epoch 33/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7356 - mse: 0.7356 - val_loss: 0.7361 - val_mse: 0.7361
# Epoch 34/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7323 - mse: 0.7323 - val_loss: 0.7385 - val_mse: 0.7385
# Epoch 35/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7327 - mse: 0.7327 - val_loss: 0.7272 - val_mse: 0.7272
# Epoch 36/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7290 - mse: 0.7290 - val_loss: 0.7338 - val_mse: 0.7338
# Epoch 37/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7299 - mse: 0.7299 - val_loss: 0.7303 - val_mse: 0.7303
# Epoch 38/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7303 - mse: 0.7303 - val_loss: 0.7356 - val_mse: 0.7356
# Epoch 39/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7299 - mse: 0.7299 - val_loss: 0.7514 - val_mse: 0.7514
# Epoch 40/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7290 - mse: 0.7290 - val_loss: 0.7546 - val_mse: 0.7546
# Epoch 41/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7293 - mse: 0.7293 - val_loss: 0.7349 - val_mse: 0.7349
# Epoch 42/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7293 - mse: 0.7293 - val_loss: 0.7445 - val_mse: 0.7445
# Epoch 43/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7258 - mse: 0.7258 - val_loss: 0.7504 - val_mse: 0.7504
# Epoch 44/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7305 - mse: 0.7305 - val_loss: 0.7358 - val_mse: 0.7358
# Epoch 45/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7239 - mse: 0.7239 - val_loss: 0.7370 - val_mse: 0.7370
# Epoch 46/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7281 - mse: 0.7281 - val_loss: 0.7384 - val_mse: 0.7384
# Epoch 47/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7285 - mse: 0.7285 - val_loss: 0.7387 - val_mse: 0.7387
# Epoch 48/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7259 - mse: 0.7259 - val_loss: 0.7379 - val_mse: 0.7379
# Epoch 49/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7242 - mse: 0.7242 - val_loss: 0.7475 - val_mse: 0.7475
# Epoch 50/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7230 - mse: 0.7230 - val_loss: 0.7629 - val_mse: 0.7629
# Epoch 51/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7228 - mse: 0.7228 - val_loss: 0.7413 - val_mse: 0.7413
# Epoch 52/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7244 - mse: 0.7244 - val_loss: 0.7458 - val_mse: 0.7458
# Epoch 53/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7242 - mse: 0.7242 - val_loss: 0.7448 - val_mse: 0.7448
# Epoch 54/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7210 - mse: 0.7210 - val_loss: 0.7542 - val_mse: 0.7542
# Epoch 55/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7218 - mse: 0.7218 - val_loss: 0.7444 - val_mse: 0.7444
# Epoch 56/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7196 - mse: 0.7196 - val_loss: 0.7498 - val_mse: 0.7498
# Epoch 57/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7198 - mse: 0.7198 - val_loss: 0.7506 - val_mse: 0.7506
# Epoch 58/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7194 - mse: 0.7194 - val_loss: 0.7449 - val_mse: 0.7449
# Epoch 59/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7242 - mse: 0.7242 - val_loss: 0.7583 - val_mse: 0.7583
# Epoch 60/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7245 - mse: 0.7245 - val_loss: 0.7490 - val_mse: 0.7490
# Epoch 61/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7221 - mse: 0.7221 - val_loss: 0.7517 - val_mse: 0.7517
# Epoch 62/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7198 - mse: 0.7198 - val_loss: 0.7379 - val_mse: 0.7379
# Epoch 63/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7180 - mse: 0.7180 - val_loss: 0.7468 - val_mse: 0.7468
# Epoch 64/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7182 - mse: 0.7182 - val_loss: 0.7441 - val_mse: 0.7441
# Epoch 65/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7152 - mse: 0.7152 - val_loss: 0.7491 - val_mse: 0.7491
# Epoch 66/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7182 - mse: 0.7182 - val_loss: 0.7544 - val_mse: 0.7544
# Epoch 67/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7161 - mse: 0.7161 - val_loss: 0.7472 - val_mse: 0.7472
# Epoch 68/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7154 - mse: 0.7154 - val_loss: 0.7448 - val_mse: 0.7448
# Epoch 69/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7180 - mse: 0.7180 - val_loss: 0.7649 - val_mse: 0.7649
# Epoch 70/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7168 - mse: 0.7168 - val_loss: 0.7453 - val_mse: 0.7453
# Epoch 71/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7161 - mse: 0.7161 - val_loss: 0.7464 - val_mse: 0.7464
# Epoch 72/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7164 - mse: 0.7164 - val_loss: 0.7520 - val_mse: 0.7520
# Epoch 73/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7127 - mse: 0.7127 - val_loss: 0.7503 - val_mse: 0.7503
# Epoch 74/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7150 - mse: 0.7150 - val_loss: 0.7492 - val_mse: 0.7492
# Epoch 75/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7171 - mse: 0.7171 - val_loss: 0.7436 - val_mse: 0.7436
# Epoch 76/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7153 - mse: 0.7153 - val_loss: 0.7551 - val_mse: 0.7551
# Epoch 77/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7162 - mse: 0.7162 - val_loss: 0.7480 - val_mse: 0.7480
# Epoch 78/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7203 - mse: 0.7203 - val_loss: 0.7718 - val_mse: 0.7718
# Epoch 79/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7196 - mse: 0.7196 - val_loss: 0.7614 - val_mse: 0.7614
# Epoch 80/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7137 - mse: 0.7137 - val_loss: 0.7560 - val_mse: 0.7560
# Epoch 81/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7128 - mse: 0.7128 - val_loss: 0.7520 - val_mse: 0.7520
# Epoch 82/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7177 - mse: 0.7177 - val_loss: 0.7529 - val_mse: 0.7529
# Epoch 83/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7110 - mse: 0.7110 - val_loss: 0.7502 - val_mse: 0.7502
# Epoch 84/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7113 - mse: 0.7113 - val_loss: 0.7624 - val_mse: 0.7624
# Epoch 85/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7161 - mse: 0.7161 - val_loss: 0.7568 - val_mse: 0.7568
# Epoch 86/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7106 - mse: 0.7106 - val_loss: 0.7559 - val_mse: 0.7559
# Epoch 87/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7133 - mse: 0.7133 - val_loss: 0.7567 - val_mse: 0.7567
# Epoch 88/100
# 151/151 [==============================] - 0s 3ms/step - loss: 0.7159 - mse: 0.7159 - val_loss: 0.7612 - val_mse: 0.7612
# Epoch 89/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7100 - mse: 0.7100 - val_loss: 0.7609 - val_mse: 0.7609
# Epoch 90/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7107 - mse: 0.7107 - val_loss: 0.7575 - val_mse: 0.7575
# Epoch 91/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7136 - mse: 0.7136 - val_loss: 0.7604 - val_mse: 0.7604
# Epoch 92/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7089 - mse: 0.7089 - val_loss: 0.7610 - val_mse: 0.7610
# Epoch 93/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7132 - mse: 0.7132 - val_loss: 0.7560 - val_mse: 0.7560
# Epoch 94/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7125 - mse: 0.7125 - val_loss: 0.7540 - val_mse: 0.7540
# Epoch 95/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7095 - mse: 0.7095 - val_loss: 0.7534 - val_mse: 0.7534
# Epoch 96/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7105 - mse: 0.7105 - val_loss: 0.7529 - val_mse: 0.7529
# Epoch 97/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7105 - mse: 0.7105 - val_loss: 0.7546 - val_mse: 0.7546
# Epoch 98/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7100 - mse: 0.7100 - val_loss: 0.7618 - val_mse: 0.7618
# Epoch 99/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7129 - mse: 0.7129 - val_loss: 0.7591 - val_mse: 0.7591
# Epoch 100/100
# 151/151 [==============================] - 0s 2ms/step - loss: 0.7081 - mse: 0.7081 - val_loss: 0.7649 - val_mse: 0.7649
# 188/188 [==============================] - 0s 1ms/step
# 47/47 [==============================] - 0s 1ms/step
# Evaluation for User ID 8405:
# Training Set Evaluation:
# MSE: 0.7148, R^2: 0.2081
#
# Test Set Evaluation:
# MSE: 0.8275, R^2: 0.0695
