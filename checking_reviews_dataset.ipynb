# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import re

# %%
# Datasets:

# Netflix Prize Dataset 
# https://www.kaggle.com/datasets/netflix-inc/netflix-prize-data?resource=download

# Large Movie Review Dataset
# https://ai.stanford.edu/~amaas/data/sentiment/

# Web data: Amazon movie reviews
# https://snap.stanford.edu/data/web-Movies.html

# MovieLens
# https://grouplens.org/datasets/movielens/

# IMdB
# https://datasets.imdbws.com/

# Metacritic

# %%
# CMU corpus
df_cmu = pd.read_csv('./MovieSummaries/MovieSummaries/movie.metadata.tsv', sep='\t', header=None,
               names=['Wikipedia_ID', 'Freebase_ID', 'Movie_name', 'Release_date', 'Box_office', 'Runtime',
                     'Movie_languages', 'Movie_countries', 'Movie_genres'])

# %%
def extract_dictionnaries_from_string(country_string):
    if isinstance(country_string, str) and country_string != '{}':
        # Use regex to find all country names (text inside double quotes after the colon)
        return ', '.join(re.findall(r'": "([^"]+)"', country_string))  # Extract country names after ": "
    return np.nan  # Return NaN for empty strings or {}

df_cmu['Cleaned_countries'] = df_cmu['Movie_countries'].apply(extract_dictionnaries_from_string)
df_cmu['Cleaned_genres'] = df_cmu['Movie_genres'].apply(extract_dictionnaries_from_string)
df_cmu['Cleaned_languages'] = df_cmu['Movie_languages'].apply(extract_dictionnaries_from_string)
df_cmu['Release_date'] = pd.to_datetime(df_cmu['Release_date'], errors='coerce')


df_cmu.drop(['Movie_countries'], axis=1, inplace=True)
df_cmu.drop(['Movie_genres'], axis=1, inplace=True)
df_cmu.drop(['Movie_languages'], axis=1, inplace=True)
df_cmu.head()
# Out:
#    Wikipedia_ID Freebase_ID  \
# 0        975900   /m/03vyhn
# 1       3196793   /m/08yl5d
# 2      28463795  /m/0crgdbh
# 3       9363483  /m/0285_cd
# 4        261236   /m/01mrr1
#
#                                           Movie_name Release_date  Box_office  \
# 0                                     Ghosts of Mars   2001-08-24  14010832.0
# 1  Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16         NaN
# 2                                        Brun bitter          NaT         NaN
# 3                                   White Of The Eye          NaT         NaN
# 4                                  A Woman in Flames          NaT         NaN
#
#    Runtime         Cleaned_countries  \
# 0     98.0  United States of America
# 1     95.0  United States of America
# 2     83.0                    Norway
# 3    110.0            United Kingdom
# 4    106.0                   Germany
#
#                                       Cleaned_genres   Cleaned_languages
# 0  Thriller, Science Fiction, Horror, Adventure, ...    English Language
# 1     Mystery, Biographical film, Drama, Crime Drama    English Language
# 2                               Crime Fiction, Drama  Norwegian Language
# 3  Thriller, Erotic thriller, Psychological thriller    English Language
# 4                                              Drama     German Language

# %%
# Movieslens 
df_movielens = pd.read_csv('Movieslens/ml-32m/movies.csv')

# %%
# TMdB
df_tmdb = pd.read_csv('TMDB_movie_dataset_v11.csv')
df_tmdb['release_date'] = pd.to_datetime(df_tmdb['release_date'], errors='coerce')

# %%
# For movielens 
def remove_date(name):
    # Remove anything in parentheses, including the space before it
    name = re.sub(r'\s*\(.*?\)', '', name)
    return name

# %%
df_movielens['cleaned_title'] = df_movielens['title'].apply(remove_date)

# %%
def normalize_movie_name(name):
    # Check if the input is not a string
    name = str(name)
    
    # Convert to lowercase
    name = name.lower()
    # Remove punctuation
    name = re.sub(r'[^\w\s]', '', name)
    # Replace multiple spaces with a single space
    name = re.sub(r'\s+', ' ', name)
    # Strip leading/trailing spaces
    name = name.strip()
    
    return name

# %%
df_cmu['normalized_name'] = df_cmu['Movie_name'].apply(normalize_movie_name)
df_movielens['normalized_name'] = df_movielens['cleaned_title'].apply(normalize_movie_name)
df_tmdb['normalized_name'] = df_tmdb['title'].apply(normalize_movie_name)

# %%
df_cmu.shape, df_movielens.shape, df_tmdb.shape
# Out:
# ((81741, 10), (87585, 5), (1129227, 25))

# %%
common_movies_cmu_movielens = pd.merge(df_cmu, df_movielens, on='normalized_name', how='inner')
commom_movies_cmu_tmdb = pd.merge(df_cmu, df_tmdb, on='normalized_name', how='inner')

common_movies_cmu_movielens = common_movies_cmu_movielens.drop_duplicates(subset='normalized_name')
commom_movies_cmu_tmdb = commom_movies_cmu_tmdb.drop_duplicates(subset='normalized_name')

common_movies_cmu_movielens.shape, commom_movies_cmu_tmdb.shape
# Out:
# ((27793, 14), (59359, 34))

# %%
common_movies_all_together = pd.merge(common_movies_cmu_movielens, commom_movies_cmu_tmdb, on='normalized_name', how='inner')
common_movies_all_together = common_movies_all_together.drop_duplicates(subset='normalized_name')
common_movies_all_together.shape
# Out:
# (27122, 47)

# %% [markdown]
# ## Finding missing values of original dataset

# %% [markdown]
# #### Cleaning the runtime

# %%
commom_movies_cmu_tmdb.columns
# Out:
# Index(['Wikipedia_ID', 'Freebase_ID', 'Movie_name', 'Release_date',
#        'Box_office', 'Runtime', 'Cleaned_countries', 'Cleaned_genres',
#        'Cleaned_languages', 'normalized_name', 'id', 'title', 'vote_average',
#        'vote_count', 'status', 'release_date', 'revenue', 'runtime', 'adult',
#        'backdrop_path', 'budget', 'homepage', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path', 'tagline',
#        'genres', 'production_companies', 'production_countries',
#        'spoken_languages', 'keywords'],
#       dtype='object')

# %%
commom_movies_cmu_tmdb_cleaned = commom_movies_cmu_tmdb.drop(columns=['id', 'title', 'vote_average', 'vote_count', 'status',
                                                                     'adult', 'backdrop_path', 'homepage', 'original_language', 
                                                                      'original_title', 'overview', 'popularity', 'poster_path', 'tagline', 
                                                                      'genres', 'production_companies', 'production_countries', 'spoken_languages', 'Freebase_ID',
                                                                     'Wikipedia_ID'])

commom_movies_cmu_tmdb_cleaned['Release_date'] = commom_movies_cmu_tmdb_cleaned['Release_date'].dt.year
commom_movies_cmu_tmdb_cleaned['release_date'] = commom_movies_cmu_tmdb_cleaned['release_date'].dt.year

# %%
commom_movies_cmu_tmdb_cleaned.head()
# Out:
#                                           Movie_name  Release_date  \
# 0                                     Ghosts of Mars        2001.0
# 1  Getting Away with Murder: The JonBenét Ramsey ...        2000.0
# 2                                   White Of The Eye           NaN
# 3                                  A Woman in Flames           NaN
# 4                                      The Gangsters        1913.0
#
#    Box_office  Runtime         Cleaned_countries  \
# 0  14010832.0     98.0  United States of America
# 1         NaN     95.0  United States of America
# 2         NaN    110.0            United Kingdom
# 3         NaN    106.0                   Germany
# 4         NaN     35.0  United States of America
#
#                                       Cleaned_genres  \
# 0  Thriller, Science Fiction, Horror, Adventure, ...
# 1     Mystery, Biographical film, Drama, Crime Drama
# 2  Thriller, Erotic thriller, Psychological thriller
# 3                                              Drama
# 4  Short Film, Silent film, Indie, Black-and-whit...
#
#                Cleaned_languages  \
# 0               English Language
# 1               English Language
# 2               English Language
# 3                German Language
# 4  Silent film, English Language
#
#                                      normalized_name  release_date   revenue  \
# 0                                     ghosts of mars        2001.0  14010832
# 1  getting away with murder the jonbenét ramsey m...        2000.0         0
# 2                                   white of the eye        1987.0         0
# 3                                  a woman in flames        1983.0         0
# 4                                      the gangsters        1913.0         0
#
#    runtime    budget    imdb_id  \
# 0       98  28000000  tt0228333
# 1       60         0  tt0245916
# 2      111         0  tt0094320
# 3      106         0  tt0083949
# 4       35         0  tt0002894
#
#                                             keywords
# 0  future, planet mars, anti hero, possession, ho...
# 1                                 colorado, jonbenet
# 2  based on novel or book, gas station, psychopat...
# 3  jealousy, eroticism, gigolo, longing, dominatr...
# 4                    slapstick comedy, keystone kops

# %%
# Check if each pair of columns are equal and store the results
# Step 1: Replace NaN in 'Release_date', 'Box_office', 'Runtime' with corresponding 'release_date', 'revenue', 'runtime'
commom_movies_cmu_tmdb_cleaned['Release_date'] = commom_movies_cmu_tmdb_cleaned['Release_date'].combine_first(commom_movies_cmu_tmdb_cleaned['release_date'])
commom_movies_cmu_tmdb_cleaned['Box_office'] = commom_movies_cmu_tmdb_cleaned['Box_office'].combine_first(commom_movies_cmu_tmdb_cleaned['revenue'])
commom_movies_cmu_tmdb_cleaned['Runtime'] = commom_movies_cmu_tmdb_cleaned['Runtime'].combine_first(commom_movies_cmu_tmdb_cleaned['runtime'])

# Step 2: Check for equality
commom_movies_cmu_tmdb_cleaned['check_release_date'] = commom_movies_cmu_tmdb_cleaned['release_date'] == commom_movies_cmu_tmdb_cleaned['Release_date']
commom_movies_cmu_tmdb_cleaned['check_revenue'] = commom_movies_cmu_tmdb_cleaned['revenue'] == commom_movies_cmu_tmdb_cleaned['Box_office']
commom_movies_cmu_tmdb_cleaned['check_runtime'] = commom_movies_cmu_tmdb_cleaned['runtime'] == commom_movies_cmu_tmdb_cleaned['Runtime']

# Optional: Check if all columns match for each row
commom_movies_cmu_tmdb_cleaned['all_match'] = commom_movies_cmu_tmdb_cleaned[['check_release_date', 'check_revenue', 'check_runtime']].all(axis=1)

print(commom_movies_cmu_tmdb_cleaned[['check_release_date', 'check_revenue', 'check_runtime', 'all_match']])
# Out:
#         check_release_date  check_revenue  check_runtime  all_match
# 0                     True           True           True       True
# 1                     True           True          False      False
# 2                     True           True          False      False
# 3                     True           True           True       True
# 4                     True           True           True       True
# ...                    ...            ...            ...        ...
# 218023                True           True           True       True
# 218024                True          False           True      False
# 218044                True           True          False      False
# 218045                True           True          False      False
# 218047                True           True           True       True
#
# [59359 rows x 4 columns]

# %%
(commom_movies_cmu_tmdb_cleaned['check_release_date'] == False).sum()
# Out:
# np.int64(5702)

# %%
(commom_movies_cmu_tmdb_cleaned['check_revenue'] == False).sum()
# Out:
# np.int64(4624)

# %%
(commom_movies_cmu_tmdb_cleaned['check_runtime'] == False).sum()
# Out:
# np.int64(23021)

# %%
sum_of_false = (commom_movies_cmu_tmdb_cleaned['all_match'] == False).sum()

# %%
for i, match in enumerate(commom_movies_cmu_tmdb_cleaned['all_match'][:200]):
    if match == False:
        print(commom_movies_cmu_tmdb_cleaned.iloc[i]['Movie_name'])
        print("release date ", commom_movies_cmu_tmdb_cleaned.iloc[i]['Release_date'], commom_movies_cmu_tmdb_cleaned.iloc[i]['release_date'])
        print("box office ", commom_movies_cmu_tmdb_cleaned.iloc[i]['Box_office'], commom_movies_cmu_tmdb_cleaned.iloc[i]['revenue'])
        print("runtime ", commom_movies_cmu_tmdb_cleaned.iloc[i]['Runtime'], commom_movies_cmu_tmdb_cleaned.iloc[i]['runtime'])
        movie_data = get_movie_data_by_id(commom_movies_cmu_tmdb_cleaned.iloc[i]['imdb_id'])
        print(movie_data)
        print("---------------")
# Out:
# Getting Away with Murder: The JonBenét Ramsey Mystery
# release date  2000.0 2000.0
# box office  0.0 0
# runtime  95.0 60
# {'title': 'Getting Away with Murder: The JonBenet Ramsey Mystery', 'runtime': ['95'], 'box_office': None, 'release_date': '2000'}
# ---------------
# White Of The Eye
# release date  1987.0 1987.0
# box office  0.0 0
# runtime  110.0 111
# {'title': 'White of the Eye', 'runtime': ['110'], 'box_office': None, 'release_date': '1987'}
# ---------------
# The Sorcerer's Apprentice
# release date  2010.0 2010.0
# box office  215283742.0 215283742
# runtime  86.0 109
# {'title': "The Sorcerer's Apprentice", 'runtime': ['109'], 'box_office': '$215,283,742', 'release_date': '2010'}
# ---------------
# Alexander's Ragtime Band
# release date  1938.0 1938.0
# box office  3600000.0 4000000
# runtime  106.0 106
# {'title': "Alexander's Ragtime Band", 'runtime': ['106'], 'box_office': None, 'release_date': '1938'}
# ---------------
# City of the Dead
# release date  2019.0 2019.0
# box office  0.0 0
# runtime  76.0 57
# None
# ---------------
# Little city
# release date  1997.0 1997.0
# box office  0.0 0
# runtime  93.0 90
# {'title': 'Little City', 'runtime': ['90'], 'box_office': None, 'release_date': '1997'}
# ---------------
# Henry V
# release date  1989.0 1989.0
# box office  10161099.0 10176701
# runtime  137.0 137
# {'title': 'Henry V', 'runtime': ['137'], 'box_office': None, 'release_date': '1989'}
# ---------------
# 1919
# release date  1997.0 1997.0
# box office  0.0 0
# runtime  99.0 8
# {'title': '1919', 'runtime': ['8'], 'box_office': None, 'release_date': '1997'}
# ---------------
# Mary Poppins
# release date  1964.0 1964.0
# box office  102272727.0 103082380
# runtime  139.0 139
# {'title': 'Mary Poppins', 'runtime': ['139'], 'box_office': '$115,272,727', 'release_date': '1964'}
# ---------------
# Keep the Change
# release date  2018.0 2018.0
# box office  0.0 0
# runtime  97.0 94
# {'title': 'Keep the Change', 'runtime': ['94'], 'box_office': None, 'release_date': '2017'}
# ---------------
# New Rose Hotel
# release date  1999.0 1999.0
# box office  21521.0 21521
# runtime  92.0 93
# {'title': 'New Rose Hotel', 'runtime': ['93'], 'box_office': None, 'release_date': '1998'}
# ---------------
# White on Rice
# release date  2009.0 2009.0
# box office  0.0 0
# runtime  82.0 83
# {'title': 'White on Rice', 'runtime': ['83'], 'box_office': None, 'release_date': '2009'}
# ---------------
# Road to Life
# release date  1931.0 1931.0
# box office  0.0 0
# runtime  104.0 108
# {'title': 'Road to Life', 'runtime': ['119'], 'box_office': None, 'release_date': '1931'}
# ---------------
# Camera Thrills
# release date  1935.0 1935.0
# box office  0.0 0
# runtime  25.0 20
# {'title': 'Camera Thrills', 'runtime': ['25'], 'box_office': None, 'release_date': '1935'}
# ---------------
# Middle Age Spread
# release date  1979.0 1979.0
# box office  0.0 0
# runtime  98.0 97
# None
# ---------------
# Baby Boy
# release date  2001.0 2001.0
# box office  29381649.0 29381649
# runtime  123.0 130
# {'title': 'Baby Boy', 'runtime': ['130'], 'box_office': None, 'release_date': '2001'}
# ---------------
# Vandanam
# release date  1989.0 1989.0
# box office  0.0 0
# runtime  168.0 180
# {'title': 'Vandanam', 'runtime': ['168'], 'box_office': None, 'release_date': '1989'}
# ---------------
# Special Effects
# release date  1984.0 1984.0
# box office  0.0 0
# runtime  93.0 106
# {'title': 'Special Effects', 'runtime': ['106'], 'box_office': None, 'release_date': '1984'}
# ---------------
# Anokha Rishta
# release date  1986.0 1986.0
# box office  0.0 0
# runtime  180.0 140
# {'title': 'Anokha Rishta', 'runtime': None, 'box_office': None, 'release_date': '1986'}
# ---------------
# They Knew What They Wanted
# release date  1940.0 1940.0
# box office  932000.0 0
# runtime  96.0 96
# {'title': 'They Knew What They Wanted', 'runtime': ['96'], 'box_office': None, 'release_date': '1940'}
# ---------------
# Karayilekku Oru Kadal Dooram
# release date  2010.0 2010.0
# box office  0.0 0
# runtime  110.0 113
# {'title': 'Karayilekku Oru Kadal Dooram', 'runtime': ['119'], 'box_office': None, 'release_date': '2011'}
# ---------------
# Mysterious Island
# release date  1961.0 1961.0
# box office  0.0 0
# runtime  100.0 101
# {'title': 'Mysterious Island', 'runtime': ['101'], 'box_office': None, 'release_date': '1961'}
# ---------------
# Woman Hungry
# release date  1930.0 1931.0
# box office  0.0 0
# runtime  65.0 65
# {'title': 'Woman Hungry', 'runtime': ['65'], 'box_office': None, 'release_date': '1931'}
# ---------------
# The Gods Must Be Crazy
# release date  1980.0 1980.0
# box office  34331783.0 60000000
# runtime  109.0 109
# {'title': 'The Gods Must Be Crazy', 'runtime': ['109'], 'box_office': '$60,000,000', 'release_date': '1980'}
# ---------------
# Joan the Woman
# release date  1917.0 1916.0
# box office  0.0 0
# runtime  138.0 138
# {'title': 'Joan the Woman', 'runtime': ['138'], 'box_office': None, 'release_date': '1916'}
# ---------------
# Jay Vejay
# release date  1977.0 1977.0
# box office  0.0 0
# runtime  152.0 145
# {'title': 'Jai-Vijay', 'runtime': ['152'], 'box_office': None, 'release_date': '1977'}
# ---------------
# My Name is Fame
# release date  2006.0 2006.0
# box office  0.0 0
# runtime  94.0 93
# {'title': 'My Name Is Fame', 'runtime': ['94'], 'box_office': None, 'release_date': '2006'}
# ---------------
# Innocence
# release date  2005.0 2005.0
# box office  0.0 0
# runtime  110.0 121
# {'title': 'Innocence', 'runtime': ['122'], 'box_office': None, 'release_date': '2004'}
# ---------------
# Hamsun
# release date  1996.0 1996.0
# box office  0.0 0
# runtime  160.0 159
# {'title': 'Hamsun', 'runtime': ['159'], 'box_office': None, 'release_date': '1996'}
# ---------------
# The Great New Wonderful
# release date  2006.0 2005.0
# box office  172055.0 0
# runtime  87.0 88
# {'title': 'The Great New Wonderful', 'runtime': ['88'], 'box_office': None, 'release_date': '2005'}
# ---------------
# Mesmerized
# release date  1986.0 1985.0
# box office  0.0 0
# runtime  94.0 97
# {'title': 'Mesmerized', 'runtime': ['94'], 'box_office': None, 'release_date': '1985'}
# ---------------
# Bruce Lee: The Lost Interview
# release date  1994.0 1971.0
# box office  0.0 0
# runtime  30.0 30
# {'title': 'Bruce Lee: The Lost Interview', 'runtime': ['30'], 'box_office': None, 'release_date': '1994'}
# ---------------
# It Came Upon the Midnight Clear
# release date  1984.0 1984.0
# box office  0.0 0
# runtime  99.0 97
# {'title': 'It Came Upon the Midnight Clear', 'runtime': ['97'], 'box_office': None, 'release_date': '1984'}
# ---------------
# Vipers
# release date  2008.0 2008.0
# box office  0.0 0
# runtime  89.0 95
# {'title': 'Vipers', 'runtime': ['95'], 'box_office': None, 'release_date': '2008'}
# ---------------
# The Human Tornado
# release date  1976.0 1976.0
# box office  0.0 0
# runtime  86.0 96
# {'title': 'The Human Tornado', 'runtime': ['96'], 'box_office': None, 'release_date': '1976'}
# ---------------
# Shivers
# release date  1975.0 1975.0
# box office  1000000.0 1000000
# runtime  89.0 88
# {'title': 'Shivers', 'runtime': ['87'], 'box_office': None, 'release_date': '1975'}
# ---------------
# My Friend Ganesha
# release date  2007.0 2007.0
# box office  0.0 0
# runtime  190.0 118
# {'title': 'My Friend Ganesha', 'runtime': ['190'], 'box_office': None, 'release_date': '2007'}
# ---------------
# One Small Step: The Story of the Space Chimps
# release date  2003.0 2003.0
# box office  0.0 0
# runtime  60.0 56
# {'title': 'One Small Step: The Story of the Space Chimps', 'runtime': ['56'], 'box_office': None, 'release_date': '2003'}
# ---------------
# The Covered Wagon
# release date  1923.0 1923.0
# box office  3500000.0 0
# runtime  23.0 98
# {'title': 'The Covered Wagon', 'runtime': ['98'], 'box_office': None, 'release_date': '1923'}
# ---------------
# The Little Hut
# release date  1957.0 1957.0
# box office  3600000.0 0
# runtime  90.0 90
# {'title': 'The Little Hut', 'runtime': ['90'], 'box_office': None, 'release_date': '1957'}
# ---------------
# Vixen!
# release date  1968.0 1968.0
# box office  8000000.0 8000000
# runtime  70.0 71
# {'title': 'Vixen!', 'runtime': ['70'], 'box_office': None, 'release_date': '1968'}
# ---------------
# Right to Love
# release date  1920.0 nan
# box office  0.0 0
# runtime  70.0 0
# {'title': 'Right to Love', 'runtime': ['92'], 'box_office': None, 'release_date': '2012'}
# ---------------
# Closing the Ring
# release date  2007.0 2007.0
# box office  0.0 0
# runtime  117.0 118
# {'title': 'Closing the Ring', 'runtime': ['118'], 'box_office': None, 'release_date': '2007'}
# ---------------
# The Boston Strangler
# release date  1968.0 1968.0
# box office  17810894.0 0
# runtime  116.0 116
# {'title': 'The Boston Strangler', 'runtime': ['116'], 'box_office': '$24,623,394', 'release_date': '1968'}
# ---------------
# The Hero: Love Story of a Spy
# release date  2003.0 2003.0
# box office  0.0 0
# runtime  182.0 160
# {'title': 'The Hero: Love Story of a Spy', 'runtime': ['160'], 'box_office': None, 'release_date': '2003'}
# ---------------
# The World of Geisha
# release date  1973.0 1973.0
# box office  0.0 0
# runtime  73.0 72
# {'title': 'World of Geisha', 'runtime': ['72'], 'box_office': None, 'release_date': '1973'}
# ---------------
# The House That Drips Blood on Alex
# release date  2010.0 2010.0
# box office  0.0 0
# runtime  13.0 14
# {'title': 'The House That Drips Blood on Alex', 'runtime': ['13'], 'box_office': None, 'release_date': '2010'}
# ---------------
# Raampur Ka Lakshman
# release date  1972.0 1972.0
# box office  0.0 0
# runtime  135.0 139
# {'title': 'Raampur Ka Lakshman', 'runtime': ['138'], 'box_office': None, 'release_date': '1972'}
# ---------------
# Dig That Uranium
# release date  1956.0 1955.0
# box office  0.0 0
# runtime  61.0 61
# {'title': 'Dig That Uranium', 'runtime': ['61'], 'box_office': None, 'release_date': '1955'}
# ---------------
# Lee Dae-ro Can't Die
# release date  2005.0 2005.0
# box office  4736013.0 0
# runtime  108.0 106
# {'title': "Lee Dae-ro Can't Die", 'runtime': ['106'], 'box_office': None, 'release_date': '2005'}
# ---------------
# The Last Trackers of the Outback
# release date  nan nan
# box office  0.0 0
# runtime  51.0 51
# {'title': 'The Last Trackers of the Outback', 'runtime': ['51'], 'box_office': None, 'release_date': '2007'}
# ---------------
# ...And Justice for All
# release date  1979.0 1979.0
# box office  33300000.0 33300000
# runtime  120.0 119
# {'title': 'And Justice for All', 'runtime': ['119'], 'box_office': '$1,582,387', 'release_date': '1979'}
# ---------------
# Children of Glory
# release date  2006.0 2006.0
# box office  0.0 0
# runtime  123.0 115
# {'title': 'Children of Glory', 'runtime': ['123'], 'box_office': None, 'release_date': '2006'}
# ---------------
# The Naked Kitchen
# release date  2009.0 2009.0
# box office  638181.0 0
# runtime  102.0 102
# {'title': 'The Naked Kitchen', 'runtime': ['102'], 'box_office': None, 'release_date': '2009'}
# ---------------
# Star!
# release date  1968.0 2001.0
# box office  4000000.0 0
# runtime  176.0 9
# {'title': 'Star', 'runtime': ['7'], 'box_office': None, 'release_date': '2001'}
# ---------------
# Mighty Mouse in the Great Space Chase
# release date  1982.0 1982.0
# box office  0.0 0
# runtime  86.0 87
# {'title': 'Mighty Mouse in the Great Space Chase', 'runtime': ['86'], 'box_office': None, 'release_date': '1982'}
# ---------------
# The Pagan
# release date  1929.0 1929.0
# box office  0.0 0
# runtime  100.0 78
# {'title': 'The Pagan', 'runtime': ['83'], 'box_office': None, 'release_date': '1929'}
# ---------------
# The Great Santini
# release date  1979.0 1979.0
# box office  4702575.0 0
# runtime  115.0 115
# {'title': 'The Great Santini', 'runtime': ['115'], 'box_office': None, 'release_date': '1979'}
# ---------------
# Carmen
# release date  2003.0 1983.0
# box office  0.0 0
# runtime  119.0 102
# {'title': 'Carmen', 'runtime': ['102'], 'box_office': None, 'release_date': '1983'}
# ---------------
# Made Men
# release date  1999.0 1999.0
# box office  0.0 0
# runtime  90.0 91
# {'title': 'Made Men', 'runtime': ['91'], 'box_office': None, 'release_date': '1999'}
# ---------------
# The Bigamist
# release date  1956.0 1953.0
# box office  0.0 0
# runtime  110.0 80
# {'title': 'The Bigamist', 'runtime': ['80'], 'box_office': None, 'release_date': '1953'}
# ---------------
# Things to Do in Denver When You're Dead
# release date  1995.0 1995.0
# box office  529677.0 529766
# runtime  115.0 116
# {'title': "Things to Do in Denver When You're Dead", 'runtime': ['115'], 'box_office': None, 'release_date': '1995'}
# ---------------
# Convoy
# release date  1978.0 1978.0
# box office  45000000.0 45000000
# runtime  111.0 110
# {'title': 'Convoy', 'runtime': ['110'], 'box_office': None, 'release_date': '1978'}
# ---------------
# The Bridge
# release date  2006.0 2006.0
# box office  179780.0 179780
# runtime  69.0 93
# {'title': 'The Bridge', 'runtime': ['94'], 'box_office': None, 'release_date': '2006'}
# ---------------
# The Castle
# release date  1997.0 1997.0
# box office  861789.0 861789
# runtime  88.0 85
# {'title': 'The Castle', 'runtime': ['85'], 'box_office': None, 'release_date': '1997'}
# ---------------
# SpongeBob vs. The Big One
# release date  2009.0 2009.0
# box office  0.0 0
# runtime  22.0 89
# {'title': 'SpongeBob SquarePants vs. The Big One', 'runtime': ['24'], 'box_office': None, 'release_date': '2009'}
# ---------------
# The Net
# release date  1995.0 1995.0
# box office  110627965.0 110627965
# runtime  115.0 114
# {'title': 'The Net', 'runtime': ['114'], 'box_office': '$110,627,965', 'release_date': '1995'}
# ---------------
# C.H.U.D.
# release date  1984.0 1984.0
# box office  4650000.0 3412497
# runtime  96.0 97
# {'title': 'C.H.U.D.', 'runtime': ['88'], 'box_office': None, 'release_date': '1984'}
# ---------------
# Emperor of the Bronx
# release date  1990.0 1990.0
# box office  0.0 0
# runtime  90.0 104
# {'title': 'Emperor of the Bronx', 'runtime': ['104'], 'box_office': None, 'release_date': '1990'}
# ---------------
# A Boy Named Sue
# release date  2000.0 2000.0
# box office  0.0 0
# runtime  58.0 69
# {'title': 'A Boy Named Sue', 'runtime': ['69'], 'box_office': None, 'release_date': '2000'}
# ---------------
# Broken Chains
# release date  nan nan
# box office  0.0 0
# runtime  88.0 88
# {'title': 'Broken Chains', 'runtime': None, 'box_office': None, 'release_date': '2021'}
# ---------------
# Black Cat, White Cat
# release date  1998.0 1998.0
# box office  351447.0 0
# runtime  135.0 127
# {'title': 'Black Cat, White Cat', 'runtime': ['127'], 'box_office': None, 'release_date': '1998'}
# ---------------
# La Marseillaise
# release date  1938.0 1938.0
# box office  0.0 0
# runtime  140.0 131
# {'title': 'La Marseillaise', 'runtime': ['135'], 'box_office': None, 'release_date': '1938'}
# ---------------
# The Insurgents
# release date  2007.0 2007.0
# box office  0.0 0
# runtime  85.0 82
# {'title': 'The Insurgents', 'runtime': ['82'], 'box_office': None, 'release_date': '2006'}
# ---------------
# Nudist Colony of the Dead
# release date  1991.0 1991.0
# box office  0.0 0
# runtime  90.0 84
# {'title': 'Nudist Colony of the Dead', 'runtime': ['90'], 'box_office': None, 'release_date': '1991'}
# ---------------
# The Astronaut Farmer
# release date  2006.0 2007.0
# box office  11130889.0 11130889
# runtime  104.0 104
# {'title': 'The Astronaut Farmer', 'runtime': ['104'], 'box_office': None, 'release_date': '2006'}
# ---------------
# Straw Dogs
# release date  1971.0 1971.0
# box office  11148828.0 3251794
# runtime  118.0 116
# {'title': 'Straw Dogs', 'runtime': ['113'], 'box_office': None, 'release_date': '1971'}
# ---------------
# Critters 3
# release date  1991.0 1991.0
# box office  0.0 0
# runtime  94.0 85
# {'title': 'Critters 3', 'runtime': ['86'], 'box_office': None, 'release_date': '1991'}
# ---------------
# City Beneath the Sea
# release date  1971.0 1953.0
# box office  0.0 0
# runtime  98.0 87
# {'title': 'City Beneath the Sea', 'runtime': ['87'], 'box_office': None, 'release_date': '1953'}
# ---------------
# Kasak
# release date  2005.0 2005.0
# box office  0.0 0
# runtime  110.0 107
# {'title': 'Kasak', 'runtime': ['107'], 'box_office': None, 'release_date': '2005'}
# ---------------
# The Bone Snatcher
# release date  2003.0 2003.0
# box office  0.0 0
# runtime  91.0 90
# {'title': 'The Bone Snatcher', 'runtime': ['90'], 'box_office': None, 'release_date': '2003'}
# ---------------
# The Third Eye
# release date  1920.0 2017.0
# box office  0.0 0
# runtime  107.0 107
# {'title': 'The 3rd Eye', 'runtime': ['107'], 'box_office': None, 'release_date': '2017'}
# ---------------
# The Seamstress
# release date  2017.0 2017.0
# box office  0.0 0
# runtime  87.0 166
# {'title': 'The Seamstress', 'runtime': ['160'], 'box_office': None, 'release_date': '2017'}
# ---------------
# Spring, Summer, Fall, Winter... and Spring
# release date  2003.0 2003.0
# box office  9524745.0 8945072
# runtime  95.0 103
# {'title': 'Spring, Summer, Fall, Winter... and Spring', 'runtime': ['103'], 'box_office': None, 'release_date': '2003'}
# ---------------
# The Catastrophe
# release date  2023.0 2023.0
# box office  0.0 0
# runtime  15.0 19
# {'title': 'The Catastrophe - IMDb', 'runtime': ['19'], 'box_office': None, 'release_date': None}
# ---------------
# Blockade
# release date  1938.0 2006.0
# box office  665523.0 0
# runtime  85.0 52
# {'title': 'Blockade', 'runtime': ['52'], 'box_office': None, 'release_date': '2006'}
# ---------------
# Grease
# release date  1978.0 1978.0
# box office  394589888.0 181813770
# runtime  225.0 110
# {'title': 'Grease', 'runtime': ['110'], 'box_office': '$394,955,690', 'release_date': '1978'}
# ---------------
# House by the River
# release date  1950.0 1950.0
# box office  0.0 0
# runtime  85.0 88
# {'title': 'House by the River', 'runtime': ['83'], 'box_office': None, 'release_date': '1950'}
# ---------------
# Pedro Páramo
# release date  1967.0 1981.0
# box office  0.0 0
# runtime  110.0 90
# {'title': 'Pedro Páramo', 'runtime': ['90'], 'box_office': None, 'release_date': '1981'}
# ---------------
# Thunderbolt
# release date  1910.0 1995.0
# box office  0.0 0
# runtime  33.0 108
# {'title': 'Thunderbolt', 'runtime': ['110'], 'box_office': None, 'release_date': '1995'}
# ---------------
# Le Grand jeu
# release date  1934.0 1992.0
# box office  0.0 0
# runtime  85.0 85
# {'title': 'Le Grand Jeu', 'runtime': ['85'], 'box_office': None, 'release_date': '1992'}
# ---------------
# The Snow Queen
# release date  2005.0 2012.0
# box office  12400000.0 12400000
# runtime  90.0 76
# {'title': 'The Snow Queen', 'runtime': ['80'], 'box_office': '$14,000,000', 'release_date': '2012'}
# ---------------
# El derecho de nacer
# release date  1952.0 1952.0
# box office  0.0 0
# runtime  110.0 90
# {'title': 'The Right to Be Born', 'runtime': ['90'], 'box_office': None, 'release_date': '1952'}
# ---------------
# Annie Laurie
# release date  1936.0 1936.0
# box office  0.0 0
# runtime  90.0 10
# {'title': 'Annie Laurie', 'runtime': ['10'], 'box_office': None, 'release_date': '1936'}
# ---------------
# What Have I Done To Deserve This?
# release date  1984.0 1984.0
# box office  706685.0 706685
# runtime  101.0 102
# {'title': 'What Have I Done to Deserve This?', 'runtime': ['101'], 'box_office': None, 'release_date': '1984'}
# ---------------
# The Iron Rose
# release date  1973.0 1973.0
# box office  0.0 0
# runtime  86.0 80
# {'title': 'The Iron Rose', 'runtime': ['86'], 'box_office': None, 'release_date': '1973'}
# ---------------
# Becoming Jane
# release date  2007.0 2007.0
# box office  37311672.0 37311672
# runtime  112.0 120
# {'title': 'Becoming Jane', 'runtime': ['120'], 'box_office': '$37,311,672', 'release_date': '2007'}
# ---------------
# Plug & Pray
# release date  2010.0 2010.0
# box office  0.0 0
# runtime  91.0 0
# {'title': 'Plug & Pray', 'runtime': ['90'], 'box_office': None, 'release_date': '2010'}
# ---------------
# André and Ursula
# release date  1955.0 1955.0
# box office  0.0 0
# runtime  80.0 0
# {'title': 'André und Ursula', 'runtime': ['80'], 'box_office': None, 'release_date': '1955'}
# ---------------
# Fly Away
# release date  2011.0 2011.0
# box office  0.0 0
# runtime  80.0 85
# {'title': 'Fly Away', 'runtime': ['80'], 'box_office': None, 'release_date': '2011'}
# ---------------
# RoboCop 3
# release date  1993.0 1993.0
# box office  10600000.0 10696210
# runtime  105.0 104
# {'title': 'RoboCop 3', 'runtime': ['104'], 'box_office': None, 'release_date': '1993'}
# ---------------
# The Stranger
# release date  1946.0 1946.0
# box office  322000000.0 322000000
# runtime  102.0 95
# {'title': 'The Stranger', 'runtime': ['95'], 'box_office': None, 'release_date': '1946'}
# ---------------

# %%
import numpy as np
import pandas as pd
from imdb import IMDb
from tqdm import tqdm

# Initialize IMDb instance
ia = IMDb()

# List to store problematic indices for later manual treatment
problematic_indices = []

# Function to get movie data using IMDb ID
def get_movie_data_by_id(imdb_id):
    # Check if imdb_id is a valid string (not NaN or empty)
    if pd.isna(imdb_id) or not isinstance(imdb_id, str) or imdb_id.strip() == "":
        return None  # Skip invalid IMDb IDs
    
    # Ensure imdb_id is a string and remove 'tt' prefix if present
    imdb_id = str(imdb_id).replace("tt", "")
    
    # Get movie details using the IMDb ID
    try:
        movie = ia.get_movie(imdb_id)
    except IMDb.IMDbError as e:
        print(f"Error fetching movie data for IMDb ID {imdb_id}: {e}")
        return None
    
    # Extract title, runtime, box office, and release date
    title = movie.get('title')
    runtime = movie.get('runtime')  # Runtime in minutes
    box_office = movie.get('box office', {}).get('Cumulative Worldwide Gross')
    
    # Try to get the release date
    release_date = movie.get('year')
    release_date = str(release_date) if release_date else None

    # Return the movie data
    return {
        'title': title,
        'runtime': runtime if runtime else "Data unavailable",
        'box_office': box_office if box_office else "Data unavailable",
        'release_date': release_date if release_date else "Data unavailable"
    }

# Iterate over the movies in your DataFrame
# for i, match in tqdm(enumerate(commom_movies_cmu_tmdb_cleaned['all_match'][:200]), total=200, ):
for i, match in enumerate(commom_movies_cmu_tmdb_cleaned['all_match']):
    if not match:  # If 'all_match' is False
        # Get the values from the relevant columns
        release_date_cmu = commom_movies_cmu_tmdb_cleaned.iloc[i]['Release_date']
        release_date_tmdb = commom_movies_cmu_tmdb_cleaned.iloc[i]['release_date']
        box_office_cmu = commom_movies_cmu_tmdb_cleaned.iloc[i]['Box_office']
        box_office_tmdb = commom_movies_cmu_tmdb_cleaned.iloc[i]['revenue']
        runtime_cmu = commom_movies_cmu_tmdb_cleaned.iloc[i]['Runtime']
        runtime_tmdb = commom_movies_cmu_tmdb_cleaned.iloc[i]['runtime']
        
        # Print the current movie name
        print(f"Movie number: {i}/{sum_of_false}")
        print(commom_movies_cmu_tmdb_cleaned.iloc[i]['Movie_name'])
        
        # Check and print release date
        if release_date_cmu != release_date_tmdb:
            print("release date mismatch:", release_date_cmu, release_date_tmdb)
            movie_data = get_movie_data_by_id(commom_movies_cmu_tmdb_cleaned.iloc[i]['imdb_id'])
            if movie_data:
                print(f"Updated release date from IMDb: {movie_data['release_date']}")
                release_date_imdb = movie_data['release_date']
                commom_movies_cmu_tmdb_cleaned.loc[i, 'Release_date'] = str(release_date_imdb)
                print("Updated release date: ", commom_movies_cmu_tmdb_cleaned.iloc[i]['Release_date'])
            else:
                problematic_indices.append(i)
        
        # Check and print box office
        if box_office_cmu != box_office_tmdb:
            print("box office mismatch:", box_office_cmu, box_office_tmdb)
            movie_data = get_movie_data_by_id(commom_movies_cmu_tmdb_cleaned.iloc[i]['imdb_id'])
            if movie_data:
                print(f"Updated box office from IMDb: {movie_data['box_office']}")
                box_office_imdb = movie_data['box_office']
                commom_movies_cmu_tmdb_cleaned.loc[i, 'Box_office'] = float(box_office_imdb)
                print("Updated box office: ", commom_movies_cmu_tmdb_cleaned.iloc[i]['Box_office'])
            else:
                problematic_indices.append(i)
        
        # Check and print runtime
        if runtime_cmu != runtime_tmdb:
            print("runtime mismatch:", runtime_cmu, runtime_tmdb)
            movie_data = get_movie_data_by_id(commom_movies_cmu_tmdb_cleaned.iloc[i]['imdb_id'])
            if movie_data:
                print(f"Updated runtime from IMDb: {movie_data['runtime']}")
                runtime_imdb = movie_data['runtime']
                commom_movies_cmu_tmdb_cleaned.loc[i, 'Runtime'] = float(runtime_imdb[0])
                print("Updated runtime: ", commom_movies_cmu_tmdb_cleaned.iloc[i]['Runtime'])
            else:
                problematic_indices.append(i)
        
        # Print final updated data
        
        
        
        print("---------------")

# After processing, print problematic indices for manual review
if problematic_indices:
    print("\nList of problematic indices that need manual review:")
    print(np.array(problematic_indices))
else:
    print("\nNo problematic indices found.")
commom_movies_cmu_tmdb_cleaned.to_csv('movies_data_cleaned.csv', index=False)
# Out:
# Movie number: 1/27397
# Getting Away with Murder: The JonBenét Ramsey Mystery
# runtime mismatch: 95.0 60
# Updated runtime from IMDb: ['95']
# Updated runtime:  95.0
# ---------------
# Movie number: 2/27397
# White Of The Eye
# runtime mismatch: 110.0 111
# Updated runtime from IMDb: ['110']
# Updated runtime:  110.0
# ---------------
# Movie number: 5/27397
# The Sorcerer's Apprentice
# runtime mismatch: 86.0 109
# Updated runtime from IMDb: ['109']
# Updated runtime:  86.0
# ---------------
# Movie number: 6/27397
# Alexander's Ragtime Band
# box office mismatch: 3600000.0 4000000.0
# Updated box office from IMDb: Data unavailable
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[132], line 80
#      78     print(f"Updated box office from IMDb: {movie_data['box_office']}")
#      79     box_office_imdb = movie_data['box_office']
# ---> 80     commom_movies_cmu_tmdb_cleaned.loc[i, 'Box_office'] = float(box_office_imdb)
#      81     print("Updated box office: ", commom_movies_cmu_tmdb_cleaned.iloc[i]['Box_office'])
#      82 else:
#
# ValueError: could not convert string to float: 'Data unavailable'

# %%
from imdb import IMDb

# Initialize IMDb instance
ia = IMDb()

# Function to get movie data
def get_movie_data(title):
    # Search for the movie title
    movies = ia.search_movie(title)
    
    if movies:
        # Get the first movie result
        movie_id = movies[0].movieID
        movie = ia.get_movie(movie_id)
        
        # Get the title, runtime, and box office
        title = movie.get('title')
        runtime = movie.get('runtime')  # Runtime in minutes
        box_office = movie.get('box office', {}).get('Cumulative Worldwide Gross')
        release_date = movie.get('release dates', [])
        
        return {
            'title': title,
            'runtime': runtime,
            'box_office': box_office
        }
    else:
        return None

def get_movie_data_by_id(imdb_id):
    # Remove 'tt' prefix if present
    if pd.isna(imdb_id) or not isinstance(imdb_id, str) or imdb_id.strip() == "":
        return None  # Skip invalid IMDb IDs
    imdb_id = str(imdb_id).replace("tt", "")
    
    # Get movie details using the IMDb ID
    movie = ia.get_movie(imdb_id)
    
    # Extract title, runtime, box office, and release date
    title = movie.get('title')
    runtime = movie.get('runtime')  # Runtime in minutes
    box_office = movie.get('box office', {}).get('Cumulative Worldwide Gross')
    release_date = movie.get('release dates', [])
    
    # Extract the first release date (if available)
    release_date = movie.get('year')
    release_date = str(release_date) if release_date else None
    
    return {
        'title': title,
        'runtime': runtime,
        'box_office': box_office,
        'release_date': release_date
    }

# Example usage
movie_data = get_movie_data("Inception")
print(movie_data)
# Out:
# {'title': 'Inception', 'runtime': ['148'], 'box_office': '$825,532,764, 06 Jan 2011'}

# %%
str(movie_data['title'])
# Out:
# 'I'

# %%
nan_rows = commom_movies_cmu_tmdb[commom_movies_cmu_tmdb['Release_date'].isna() & commom_movies_cmu_tmdb['release_date'].isna()]

# %%
nan_rows
# Out:
#         Wikipedia_ID Freebase_ID                        Movie_name  \
# 189         28415406  /m/0crj1f3  The Last Trackers of the Outback
# 421         32972053  /m/0h541q3                     Broken Chains
# 1034         1393873   /m/04z2kf                     Loopy De Loop
# 4100         6685838   /m/0gh6t8                        Engagement
# 4661        20904652  /m/05b4w4s                        Prem Vivah
# ...              ...         ...                               ...
# 210014      32501689  /m/0gmf5cb          The Return of Billy Jack
# 211337      28372388  /m/0crj3bg                 Amar Praner Priya
# 211653      21901669  /m/05nztkz                          Shoebite
# 215029      22963595  /m/063ych2                           Chaitra
# 216629       7990625  /m/026mp4r                      One Shot Sam
#
#        Release_date  Box_office  Runtime  \
# 189             NaN         NaN      NaN
# 421             NaN         NaN      NaN
# 1034            NaN         NaN      NaN
# 4100            NaN         NaN      NaN
# 4661            NaN         NaN    150.0
# ...             ...         ...      ...
# 210014          NaN         NaN      NaN
# 211337          NaN         NaN    160.0
# 211653          NaN         NaN      NaN
# 215029          NaN         NaN     20.0
# 216629          NaN         NaN     90.0
#
#                                           Movie_languages  \
# 189                    {"/m/02h40lc": "English Language"}
# 421                                                    {}
# 1034                                                   {}
# 4100                                                   {}
# 4661                       {"/m/03k50": "Hindi Language"}
# ...                                                   ...
# 210014                                                 {}
# 211337                                                 {}
# 211653                     {"/m/03k50": "Hindi Language"}
# 215029  {"/m/055qm": "Marathi Language", "/m/02h40lc":...
# 216629                 {"/m/02h40lc": "English Language"}
#
#                                           Movie_countries  \
# 189     {"/m/0f8l9c": "France", "/m/0chghy": "Australia"}
# 421                                                    {}
# 1034                                                   {}
# 4100                         {"/m/0hzlz": "South Africa"}
# 4661                                {"/m/03rk0": "India"}
# ...                                                   ...
# 210014                                                 {}
# 211337                                                 {}
# 211653                              {"/m/03rk0": "India"}
# 215029                              {"/m/03rk0": "India"}
# 216629          {"/m/09c7w0": "United States of America"}
#
#                                              Movie_genres  \
# 189                           {"/m/0jtdp": "Documentary"}
# 421     {"/m/02l7c8": "Romance Film", "/m/07s9rl0": "D...
# 1034    {"/m/05p553": "Comedy film", "/m/0hqxf": "Fami...
# 4100    {"/m/02l7c8": "Romance Film", "/m/07s9rl0": "D...
# 4661                        {"/m/02l7c8": "Romance Film"}
# ...                                                   ...
# 210014                           {"/m/02kdv5l": "Action"}
# 211337                    {"/m/06cvj": "Romantic comedy"}
# 211653                      {"/m/02l7c8": "Romance Film"}
# 215029                        {"/m/02hmvc": "Short Film"}
# 216629                      {"/m/0lsxr": "Crime Fiction"}
#
#                          normalized_name  ...  \
# 189     the last trackers of the outback  ...
# 421                        broken chains  ...
# 1034                       loopy de loop  ...
# 4100                          engagement  ...
# 4661                          prem vivah  ...
# ...                                  ...  ...
# 210014          the return of billy jack  ...
# 211337                 amar praner priya  ...
# 211653                          shoebite  ...
# 215029                           chaitra  ...
# 216629                      one shot sam  ...
#
#                           original_title  \
# 189     The Last Trackers of the Outback
# 421                        Broken Chains
# 1034                       Loopy De Loop
# 4100                          Engagement
# 4661                          Prem Vivah
# ...                                  ...
# 210014          The Return of Billy Jack
# 211337                 Amar Praner Priya
# 211653                          Shoebite
# 215029                            சைத்ரா
# 216629                      One Shot Sam
#
#                                                  overview  popularity  \
# 189     For millenniums, Aborigines used tracking to s...       0.600
# 421     An unflinching exposé on the racial wealth gap...       0.600
# 1034                                                  NaN       0.000
# 4100                                                  NaN       0.000
# 4661                                                  NaN       0.000
# ...                                                   ...         ...
# 210014  Billy Jack returns to bring down a child porno...       1.728
# 211337  Prem is helpful to his friends and solves thei...       0.000
# 211653  Shoebite is the story of a man in his early 60...       1.400
# 215029  Chaitra, Kathir’s mentally unstable housewife,...       0.600
# 216629  This film follows One Shot Sam, played by Dona...       0.000
#
#                              poster_path                   tagline  \
# 189                                  NaN                       NaN
# 421     /c2eQ20dPmtJvhYpANcxwHmiBRJD.jpg                       NaN
# 1034                                 NaN                       NaN
# 4100                                 NaN                       NaN
# 4661                                 NaN                       NaN
# ...                                  ...                       ...
# 210014   /xOVgUMTlJ84jGd4uP6r1KXE8c6.jpg                       NaN
# 211337                               NaN                       NaN
# 211653  /zFyzTICg0EpVy8a5v5pUcF1ZzpE.jpg                       NaN
# 215029  /mL2V6glU3pMGR9jHt6VJUPIb1RJ.jpg  The Beginning of the End
# 216629                               NaN                       NaN
#
#                       genres    production_companies  \
# 189                      NaN                     NaN
# 421              Documentary                     NaN
# 1034                     NaN                     NaN
# 4100                     NaN                     NaN
# 4661                     NaN                     NaN
# ...                      ...                     ...
# 210014  Drama, Action, Crime  Billy Jack Enterprises
# 211337                   NaN                     NaN
# 211653                 Drama     UTV Motion Pictures
# 215029      Horror, Thriller   mars productions (in)
# 216629                   NaN                     NaN
#
#             production_countries  spoken_languages                  keywords
# 189                          NaN               NaN                       NaN
# 421                          NaN           English                       NaN
# 1034                         NaN               NaN                       NaN
# 4100                         NaN               NaN                       NaN
# 4661                         NaN               NaN                       NaN
# ...                          ...               ...                       ...
# 210014  United States of America           English  child pornography, mafia
# 211337                       NaN               NaN                       NaN
# 211653                     India             Hindi                       NaN
# 215029                       NaN             Tamil                       NaN
# 216629                       NaN               NaN                       NaN
#
# [139 rows x 34 columns]

# %%
movies_name = df_cmu['Movie_name'].unique()
len(movies_name)
# Out:
# 75478

# %%
#df_netflix = pd.read_csv('./Netflix/movie_titles.csv', encoding="ISO-8859-1", header=None, names=['movie_id', 'year_of_release', 'title'],
#                         parse_dates=['year_of_release'],on_bad_lines='skip')

# %%
#movies_name_netflix = df_netflix['title'].unique()
#len(movies_name_netflix)

"""
import pandas as pd

# Assuming your DataFrame is named df and the movie ID column is named 'movie_id'
all_ids = set(range(1, 17771))  # Full range of IDs from 1 to 17770
existing_ids = set(df['movie_id'])  # Existing IDs in the DataFrame

# Find missing IDs
missing_ids = sorted(all_ids - existing_ids)

print("Missing IDs:", missing_ids)
"""
# Out:
# 17026

# %%
movielens.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movielens.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres                cleaned_title
# 0  Adventure|Animation|Children|Comedy|Fantasy                    Toy Story
# 1                   Adventure|Children|Fantasy                      Jumanji
# 2                               Comedy|Romance             Grumpier Old Men
# 3                         Comedy|Drama|Romance            Waiting to Exhale
# 4                                       Comedy  Father of the Bride Part II

# %%
#df_imdb = pd.read_csv('IMdB/title.basics.tsv', sep='\t', encoding='utf-8', na_values=['\n'])
# Out:
# C:\Users\Corentin\AppData\Local\Temp\ipykernel_9900\3951529100.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_imdb = pd.read_csv(

# %%
#a = pd.DataFrame(df_imdb['originalTitle'].unique(), columns=['originalTitle'])
#a.head()
# Out:
#             originalTitle
# 0              Carmencita
# 1  Le clown et ses chiens
# 2          Pauvre Pierrot
# 3             Un bon bock
# 4        Blacksmith Scene

# %%
#a.shape
# Out:
# (5060993, 1)

# %%
common_movies_cmu_movielens = pd.merge(common_movies_cmu_plot_summaries, movielens, on='normalized_name', how='inner')
#common_movies_cmu_netflix = pd.merge(common_movies_cmu_plot_summaries, df_netflix, on='normalized_name', how='inner')
#commom_movies_cmu_imdb = pd.merge(common_movies_cmu_plot_summaries, df_imdb, on='normalized_name', how='inner')
commom_movies_cmu_tmdb = pd.merge(common_movies_cmu_plot_summaries, df_tmdb, on='normalized_name', how='inner')


common_movies_cmu_movielens = common_movies_cmu_movielens.drop_duplicates(subset='normalized_name')
#common_movies_cmu_netflix = common_movies_cmu_netflix.drop_duplicates(subset='normalized_name')
#commom_movies_cmu_imdb = commom_movies_cmu_imdb.drop_duplicates(subset='normalized_name')
commom_movies_cmu_tmdb = commom_movies_cmu_tmdb.drop_duplicates(subset='normalized_name')

common_movies_cmu_movielens2 = pd.merge(df_cmu, movielens, on='normalized_name', how='inner')
#common_movies_cmu_netflix2 = pd.merge(df_cmu, df_netflix, on='normalized_name', how='inner')
#commom_movies_cmu_imdb2 = pd.merge(df_cmu, df_imdb, on='normalized_name', how='inner')
commom_movies_cmu_tmdb2 = pd.merge(df_cmu, df_tmdb, on='normalized_name', how='inner')


common_movies_cmu_movielens2 = common_movies_cmu_movielens2.drop_duplicates(subset='normalized_name')
#common_movies_cmu_netflix2 = common_movies_cmu_netflix2.drop_duplicates(subset='normalized_name')
#commom_movies_cmu_imdb2 = commom_movies_cmu_imdb2.drop_duplicates(subset='normalized_name')
commom_movies_cmu_tmdb2 = commom_movies_cmu_tmdb2.drop_duplicates(subset='normalized_name')

# %%
df_cmu.shape, df_netflix.shape, movielens.shape, df_imdb.shape, common_movies_cmu_plot_summaries.shape
# Out:
# ((81741, 10), (17434, 4), (87585, 5), (11219540, 10), (42204, 11))

# %%
df_tmdb
# Out:
#               id                          title  vote_average  vote_count  \
# 0          27205                      Inception         8.364       34495
# 1         157336                   Interstellar         8.417       32571
# 2            155                The Dark Knight         8.512       30619
# 3          19995                         Avatar         7.573       29815
# 4          24428                   The Avengers         7.710       29166
# ...          ...                            ...           ...         ...
# 1129222   729506                     Love Lives         0.000           0
# 1129223   729508  Close your eyes to see better         0.000           0
# 1129224   729509             Men Who Don't Work         0.000           0
# 1129225   729510    Torture in Stammheim prison         0.000           0
# 1129226  1384417               Brownout Capital         0.000           0
#
#            status release_date     revenue  runtime  adult  \
# 0        Released   2010-07-15   825532764      148  False
# 1        Released   2014-11-05   701729206      169  False
# 2        Released   2008-07-16  1004558444      152  False
# 3        Released   2009-12-15  2923706026      162  False
# 4        Released   2012-04-25  1518815515      143  False
# ...           ...          ...         ...      ...    ...
# 1129222  Released          NaN           0       14  False
# 1129223  Released   1986-01-01           0       23  False
# 1129224  Released   2011-09-29           0       12  False
# 1129225  Released   2005-01-01           0       45  False
# 1129226  Released          NaN           0       14  False
#
#                             backdrop_path  ...  \
# 0        /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1        /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2        /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3        /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4        /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
# ...                                   ...  ...
# 1129222                               NaN  ...
# 1129223                               NaN  ...
# 1129224                               NaN  ...
# 1129225                               NaN  ...
# 1129226                               NaN  ...
#
#                                       original_title  \
# 0                                          Inception
# 1                                       Interstellar
# 2                                    The Dark Knight
# 3                                             Avatar
# 4                                       The Avengers
# ...                                              ...
# 1129222                                   Love Lives
# 1129223       Die Augen schließen um besser zu sehen
# 1129224                           Men Who Don't Work
# 1129225  Folter in Stammheim? Die Propaganda der RAF
# 1129226                             Brownout Capital
#
#                                                   overview popularity  \
# 0        Cobb, a skilled thief who commits corporate es...     83.952
# 1        The adventures of a group of explorers who mak...    140.241
# 2        Batman raises the stakes in his war on crime. ...    130.643
# 3        In the 22nd century, a paraplegic Marine is di...     79.932
# 4        When an unexpected enemy emerges and threatens...     98.082
# ...                                                    ...        ...
# 1129222  Filmed over several days in Sheffield, UK, thi...      0.600
# 1129223  This video was made in 1986 by residents of Ha...      0.600
# 1129224  When an unusual family moves into a house on h...      0.600
# 1129225  When a law enforcement officer unravels the ce...      0.600
# 1129226  In the outskirts of Palawan, a man hunts for i...      0.000
#
#                               poster_path  \
# 0        /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1        /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2        /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3        /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4         /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
# ...                                   ...
# 1129222                               NaN
# 1129223                               NaN
# 1129224  /eTVp4OyCrbNkKBsKz30Dtc7sVdG.jpg
# 1129225                               NaN
# 1129226                               NaN
#
#                                                    tagline  \
# 0                     Your mind is the scene of the crime.
# 1        Mankind was born on Earth. It was never meant ...
# 2                        Welcome to a world without rules.
# 3                              Enter the world of Pandora.
# 4                                  Some assembly required.
# ...                                                    ...
# 1129222                                                NaN
# 1129223                                                NaN
# 1129224                                                NaN
# 1129225                                                NaN
# 1129226                                                NaN
#
#                                               genres  \
# 0                 Action, Science Fiction, Adventure
# 1                  Adventure, Drama, Science Fiction
# 2                     Drama, Action, Crime, Thriller
# 3        Action, Adventure, Fantasy, Science Fiction
# 4                 Science Fiction, Action, Adventure
# ...                                              ...
# 1129222                                          NaN
# 1129223                                          NaN
# 1129224                                        Drama
# 1129225                                          NaN
# 1129226                                          NaN
#
#                                       production_companies  \
# 0        Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1        Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2        DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3        Dune Entertainment, Lightstorm Entertainment, ...
# 4                                           Marvel Studios
# ...                                                    ...
# 1129222                                                NaN
# 1129223                                                NaN
# 1129224                                                NaN
# 1129225                                                NaN
# 1129226                                                NaN
#
#                              production_countries  \
# 0        United Kingdom, United States of America
# 1        United Kingdom, United States of America
# 2        United Kingdom, United States of America
# 3        United States of America, United Kingdom
# 4                        United States of America
# ...                                           ...
# 1129222                                       NaN
# 1129223                                       NaN
# 1129224                  United States of America
# 1129225                                       NaN
# 1129226                                       NaN
#
#                            spoken_languages  \
# 0        English, French, Japanese, Swahili
# 1                                   English
# 2                         English, Mandarin
# 3                          English, Spanish
# 4                   English, Hindi, Russian
# ...                                     ...
# 1129222                                 NaN
# 1129223                              German
# 1129224                             English
# 1129225                              German
# 1129226                                 NaN
#
#                                                   keywords
# 0        rescue, mission, dream, airplane, paris, franc...
# 1        rescue, future, spacecraft, race against time,...
# 2        joker, sadism, chaos, secret identity, crime f...
# 3        future, society, culture clash, space travel, ...
# 4        new york city, superhero, shield, based on com...
# ...                                                    ...
# 1129222                                                NaN
# 1129223                                                NaN
# 1129224                                                NaN
# 1129225                                                NaN
# 1129226                                                NaN
#
# [1129227 rows x 24 columns]

# %%
commom_movies_cmu_tmdb.head()
# Out:
#     Wikipedia_ID Freebase_ID                 Movie_name Release_date  \
# 0         975900   /m/03vyhn             Ghosts of Mars   2001-08-24
# 1        9363483  /m/0285_cd           White Of The Eye         1987
# 2         261236   /m/01mrr1          A Woman in Flames         1983
# 3       18998739  /m/04jcqvw  The Sorcerer's Apprentice         2002
# 10       6631279   /m/0gffwj                Little city   1997-04-04
#
#     Box_office  Runtime                     Movie_languages  \
# 0   14010832.0     98.0  {"/m/02h40lc": "English Language"}
# 1          NaN    110.0  {"/m/02h40lc": "English Language"}
# 2          NaN    106.0   {"/m/04306rv": "German Language"}
# 3          NaN     86.0  {"/m/02h40lc": "English Language"}
# 10         NaN     93.0  {"/m/02h40lc": "English Language"}
#
#                               Movie_countries  \
# 0   {"/m/09c7w0": "United States of America"}
# 1              {"/m/07ssc": "United Kingdom"}
# 2                     {"/m/0345h": "Germany"}
# 3                {"/m/0hzlz": "South Africa"}
# 10  {"/m/09c7w0": "United States of America"}
#
#                                          Movie_genres  \
# 0   {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1   {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 2                             {"/m/07s9rl0": "Drama"}
# 3   {"/m/0hqxf": "Family Film", "/m/01hmnh": "Fant...
# 10  {"/m/06cvj": "Romantic comedy", "/m/0hj3n0w": ...
#
#              normalized_name  ...             original_title  \
# 0             ghosts of mars  ...             Ghosts of Mars
# 1           white of the eye  ...           White of the Eye
# 2          a woman in flames  ...        Die flambierte Frau
# 3   the sorcerers apprentice  ...  The Sorcerer's Apprentice
# 10               little city  ...                Little City
#
#                                              overview popularity  \
# 0   In 2176, a Martian police unit is sent to pick...     14.189
# 1   In a wealthy and isolated desert community, a ...      8.297
# 2   Eva, an upper-class housewife, frustratedly le...      2.801
# 3   Balthazar Blake is a master sorcerer in modern...     28.585
# 10  Best friends Adam and Kevin have a lot in comm...      1.556
#
#                          poster_path  \
# 0   /i2zztssCIbahGES1fdfWFmDXian.jpg
# 1   /aLFoGmQpknOvcyx4imCP7Fuvoip.jpg
# 2   /iKeCVR0x8vnRXLtjwjZ7EuVFlo7.jpg
# 3   /b5pIUsGll0418NyfNA5eYCI9aoK.jpg
# 10  /fIynQQgyxWCs0kNJ7YHKTRNwaZI.jpg
#
#                                           tagline  \
# 0               Terror is the same on any planet.
# 1            No woman is safe… while he is loose!
# 2                                             NaN
# 3                      It's The Coolest Job Ever.
# 10  When your one and only... isn't the only one!
#
#                              genres  \
# 0   Action, Horror, Science Fiction
# 1                  Horror, Thriller
# 2                             Drama
# 3        Fantasy, Adventure, Action
# 10                  Comedy, Romance
#
#                                  production_companies  \
# 0   Animationwerks, Screen Gems, Storm King Produc...
# 1                            Mrs. White's Productions
# 2                      Dieter Geissler Filmproduktion
# 3   Walt Disney Pictures, Jerry Bruckheimer Films,...
# 10                    Bandeira Entertainment, Miramax
#
#         production_countries  spoken_languages  \
# 0   United States of America           English
# 1             United Kingdom           English
# 2                    Germany            German
# 3   United States of America           English
# 10                       NaN           English
#
#                                              keywords
# 0   future, planet mars, anti hero, possession, ho...
# 1   based on novel or book, gas station, psychopat...
# 2   jealousy, eroticism, gigolo, longing, dominatr...
# 3   witch, mission, magic, mystic, castle, sorcere...
# 10                                                NaN
#
# [5 rows x 35 columns]

# %%
commom_movies_cmu_tmdb.drop(columns=['vote_average', 'vote_count', 'status', 'adult', 'backdrop_path'])

# %%
'budget', 'homepage',
       'imdb_id', 'original_language', 'original_title', 'overview',
       'popularity', 'poster_path', 'tagline', 'genres',
       'production_companies', 'production_countries', 'spoken_languages',
       'keywords'],
      dtype='object')

# %%
df_plot_summaries = pd.read_csv('./MovieSummaries/MovieSummaries/plot_summaries.txt', sep='\t', header=None, names=['Wikipedia_ID', 'Plot'])

# %%
df_plot_summaries.head()
# Out:
#    Wikipedia_ID                                               Plot
# 0      23890098  Shlykov, a hard-working taxi driver and Lyosha...
# 1      31186339  The nation of Panem consists of a wealthy Capi...
# 2      20663735  Poovalli Induchoodan  is sentenced for six yea...
# 3       2231378  The Lemon Drop Kid , a New York City swindler,...
# 4        595909  Seventh-day Adventist Church pastor Michael Ch...

# %%
common_movies_cmu_plot_summaries = pd.merge(df_cmu, df_plot_summaries, on='Wikipedia_ID', how='inner')
common_movies_cmu_plot_summaries = common_movies_cmu_plot_summaries.drop_duplicates(subset='Wikipedia_ID')
common_movies_cmu_plot_summaries.head()
# Out:
#    Wikipedia_ID Freebase_ID                 Movie_name Release_date  \
# 0        975900   /m/03vyhn             Ghosts of Mars   2001-08-24
# 1       9363483  /m/0285_cd           White Of The Eye         1987
# 2        261236   /m/01mrr1          A Woman in Flames         1983
# 3      18998739  /m/04jcqvw  The Sorcerer's Apprentice         2002
# 4       6631279   /m/0gffwj                Little city   1997-04-04
#
#    Box_office  Runtime                     Movie_languages  \
# 0  14010832.0     98.0  {"/m/02h40lc": "English Language"}
# 1         NaN    110.0  {"/m/02h40lc": "English Language"}
# 2         NaN    106.0   {"/m/04306rv": "German Language"}
# 3         NaN     86.0  {"/m/02h40lc": "English Language"}
# 4         NaN     93.0  {"/m/02h40lc": "English Language"}
#
#                              Movie_countries  \
# 0  {"/m/09c7w0": "United States of America"}
# 1             {"/m/07ssc": "United Kingdom"}
# 2                    {"/m/0345h": "Germany"}
# 3               {"/m/0hzlz": "South Africa"}
# 4  {"/m/09c7w0": "United States of America"}
#
#                                         Movie_genres  \
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 2                            {"/m/07s9rl0": "Drama"}
# 3  {"/m/0hqxf": "Family Film", "/m/01hmnh": "Fant...
# 4  {"/m/06cvj": "Romantic comedy", "/m/0hj3n0w": ...
#
#             normalized_name                                               Plot
# 0            ghosts of mars  Set in the second half of the 22nd century, th...
# 1          white of the eye  A series of murders of rich young women throug...
# 2         a woman in flames  Eva, an upper class housewife, becomes frustra...
# 3  the sorcerers apprentice  Every hundred years, the evil Morgana  returns...
# 4               little city  Adam, a San Francisco-based artist who works a...

# %%
# Get reviews
movielens_reviews = pd.read_csv('Movieslens/ml-32m/ratings.csv')

# %%
movielens_reviews.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1       17     4.0  944249077
# 1       1       25     1.0  944250228
# 2       1       29     2.0  943230976
# 3       1       30     5.0  944249077
# 4       1       32     5.0  943228858

# %%
test = movielens_reviews.groupby(['userId', 'movieId'])
test

# %%
high_ratings = movielens_reviews[movielens_reviews['rating'] >= 4.0]


users_with_high_ratings = (
    high_ratings.groupby('movieId')
    .filter(lambda x: x['userId'].nunique() > 1)
)

print(users_with_high_ratings)
# Out:
#           userId  movieId  rating   timestamp
# 0              1       17     4.0   944249077
# 3              1       30     5.0   944249077
# 4              1       32     5.0   943228858
# 7              1       80     5.0   944248943
# 9              1      111     5.0   944249008
# ...          ...      ...     ...         ...
# 32000195  200948    72998     5.0  1350423889
# 32000196  200948    74458     4.5  1350423822
# 32000197  200948    76093     5.0  1287223498
# 32000199  200948    79702     4.5  1294412589
# 32000203  200948    87304     4.5  1350423523
#
# [15921569 rows x 4 columns]

# %%
df_tmdb['keywords'][0]
# Out:
# 'rescue, mission, dream, airplane, paris, france, virtual reality, kidnapping, philosophy, spy, allegory, manipulation, car crash, heist, memory, architecture, los angeles, california, dream world, subconscious'

# %%
df_tmdb.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#                                             overview popularity  \
# 0  Cobb, a skilled thief who commits corporate es...     83.952
# 1  The adventures of a group of explorers who mak...    140.241
# 2  Batman raises the stakes in his war on crime. ...    130.643
# 3  In the 22nd century, a paraplegic Marine is di...     79.932
# 4  When an unexpected enemy emerges and threatens...     98.082
#
#                         poster_path  \
# 0  /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1  /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2  /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4   /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
#
#                                              tagline  \
# 0               Your mind is the scene of the crime.
# 1  Mankind was born on Earth. It was never meant ...
# 2                  Welcome to a world without rules.
# 3                        Enter the world of Pandora.
# 4                            Some assembly required.
#
#                                         genres  \
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# 2               Drama, Action, Crime, Thriller
# 3  Action, Adventure, Fantasy, Science Fiction
# 4           Science Fiction, Action, Adventure
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2  DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3  Dune Entertainment, Lightstorm Entertainment, ...
# 4                                     Marvel Studios
#
#                        production_countries  \
# 0  United Kingdom, United States of America
# 1  United Kingdom, United States of America
# 2  United Kingdom, United States of America
# 3  United States of America, United Kingdom
# 4                  United States of America
#
#                      spoken_languages  \
# 0  English, French, Japanese, Swahili
# 1                             English
# 2                   English, Mandarin
# 3                    English, Spanish
# 4             English, Hindi, Russian
#
#                                             keywords  normalized_name
# 0  rescue, mission, dream, airplane, paris, franc...        inception
# 1  rescue, future, spacecraft, race against time,...     interstellar
# 2  joker, sadism, chaos, secret identity, crime f...  the dark knight
# 3  future, society, culture clash, space travel, ...           avatar
# 4  new york city, superhero, shield, based on com...     the avengers
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Find missing information in CMU using TMdB dataset

# %%
df_cmu.head()
# Out:
#    Wikipedia_ID Freebase_ID  \
# 0        975900   /m/03vyhn
# 1       3196793   /m/08yl5d
# 2      28463795  /m/0crgdbh
# 3       9363483  /m/0285_cd
# 4        261236   /m/01mrr1
#
#                                           Movie_name Release_date  Box_office  \
# 0                                     Ghosts of Mars   2001-08-24  14010832.0
# 1  Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16         NaN
# 2                                        Brun bitter         1988         NaN
# 3                                   White Of The Eye         1987         NaN
# 4                                  A Woman in Flames         1983         NaN
#
#    Runtime                     Movie_languages  \
# 0     98.0  {"/m/02h40lc": "English Language"}
# 1     95.0  {"/m/02h40lc": "English Language"}
# 2     83.0  {"/m/05f_3": "Norwegian Language"}
# 3    110.0  {"/m/02h40lc": "English Language"}
# 4    106.0   {"/m/04306rv": "German Language"}
#
#                              Movie_countries  \
# 0  {"/m/09c7w0": "United States of America"}
# 1  {"/m/09c7w0": "United States of America"}
# 2                     {"/m/05b4w": "Norway"}
# 3             {"/m/07ssc": "United Kingdom"}
# 4                    {"/m/0345h": "Germany"}
#
#                                         Movie_genres  \
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1  {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2  {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4                            {"/m/07s9rl0": "Drama"}
#
#                                      normalized_name
# 0                                     ghosts of mars
# 1  getting away with murder the jonbenét ramsey m...
# 2                                        brun bitter
# 3                                   white of the eye
# 4                                  a woman in flames

# %%
df_cmu.isna().sum()
# Out:
# Wikipedia_ID           0
# Freebase_ID            0
# Movie_name             0
# Release_date        6902
# Box_office         73340
# Runtime            20450
# Movie_languages        0
# Movie_countries        0
# Movie_genres           0
# normalized_name        0
# dtype: int64

# %%
nan_indices_release_date = df_cmu[df_cmu['Box_office'].isna()].index

# %%
for i in nan_indices_release_date[:10]:
    name = normalize_movie_name(df_cmu.iloc[i]['Movie_name'])
    print(df_cmu.iloc[i]['Movie_name'])
    print(df_cmu.iloc[i]['Release_date'])
    print(df_tmdb[df_tmdb['normalized_name'] == name]['release_date'])
    print(df_tmdb[df_tmdb['normalized_name'] == name]['title'])
    print('--------------------')
# Out:
# The Mechanical Monsters
# nan
# 31444    1941-11-28
# Name: release_date, dtype: object
# 31444    The Mechanical Monsters
# Name: title, dtype: object
# --------------------
# Boadicea
# nan
# 385410    1966-09-22
# 896601    1927-09-05
# Name: release_date, dtype: object
# 385410    Boadicea
# 896601    Boadicea
# Name: title, dtype: object
# --------------------
# Les Indiens sont encore loin
# nan
# Series([], Name: release_date, dtype: object)
# Series([], Name: title, dtype: object)
# --------------------
# Donald's Crime
# nan
# 35909    1945-06-29
# Name: release_date, dtype: object
# 35909    Donald's Crime
# Name: title, dtype: object
# --------------------
# The Last Trackers of the Outback
# nan
# 958010    NaN
# Name: release_date, dtype: object
# 958010    The Last Trackers of the Outback
# Name: title, dtype: object
# --------------------
# Mighty Mouse in the Great Space Chase
# nan
# 130344    1982-12-10
# Name: release_date, dtype: object
# 130344    Mighty Mouse in the Great Space Chase
# Name: title, dtype: object
# --------------------
# Ethe Naasaval
# nan
# 902763    1984-06-15
# Name: release_date, dtype: object
# 902763    Ethe Naasaval
# Name: title, dtype: object
# --------------------
# Is There a Doctor in the Mouse?
# nan
# 47465    1964-03-24
# Name: release_date, dtype: object
# 47465    Is There a Doctor in the Mouse?
# Name: title, dtype: object
# --------------------
# Peddarayudu
# nan
# Series([], Name: release_date, dtype: object)
# Series([], Name: title, dtype: object)
# --------------------
# 14 Going on 30
# nan
# 62738    1988-03-06
# Name: release_date, dtype: object
# 62738    14 Going on 30
# Name: title, dtype: object
# --------------------

# %%
df_tmdb
# Out:
#               id                          title  vote_average  vote_count  \
# 0          27205                      Inception         8.364       34495
# 1         157336                   Interstellar         8.417       32571
# 2            155                The Dark Knight         8.512       30619
# 3          19995                         Avatar         7.573       29815
# 4          24428                   The Avengers         7.710       29166
# ...          ...                            ...           ...         ...
# 1129222   729506                     Love Lives         0.000           0
# 1129223   729508  Close your eyes to see better         0.000           0
# 1129224   729509             Men Who Don't Work         0.000           0
# 1129225   729510    Torture in Stammheim prison         0.000           0
# 1129226  1384417               Brownout Capital         0.000           0
#
#            status release_date     revenue  runtime  adult  \
# 0        Released   2010-07-15   825532764      148  False
# 1        Released   2014-11-05   701729206      169  False
# 2        Released   2008-07-16  1004558444      152  False
# 3        Released   2009-12-15  2923706026      162  False
# 4        Released   2012-04-25  1518815515      143  False
# ...           ...          ...         ...      ...    ...
# 1129222  Released          NaN           0       14  False
# 1129223  Released   1986-01-01           0       23  False
# 1129224  Released   2011-09-29           0       12  False
# 1129225  Released   2005-01-01           0       45  False
# 1129226  Released          NaN           0       14  False
#
#                             backdrop_path  ...  \
# 0        /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1        /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2        /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3        /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4        /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
# ...                                   ...  ...
# 1129222                               NaN  ...
# 1129223                               NaN  ...
# 1129224                               NaN  ...
# 1129225                               NaN  ...
# 1129226                               NaN  ...
#
#                                                   overview popularity  \
# 0        Cobb, a skilled thief who commits corporate es...     83.952
# 1        The adventures of a group of explorers who mak...    140.241
# 2        Batman raises the stakes in his war on crime. ...    130.643
# 3        In the 22nd century, a paraplegic Marine is di...     79.932
# 4        When an unexpected enemy emerges and threatens...     98.082
# ...                                                    ...        ...
# 1129222  Filmed over several days in Sheffield, UK, thi...      0.600
# 1129223  This video was made in 1986 by residents of Ha...      0.600
# 1129224  When an unusual family moves into a house on h...      0.600
# 1129225  When a law enforcement officer unravels the ce...      0.600
# 1129226  In the outskirts of Palawan, a man hunts for i...      0.000
#
#                               poster_path  \
# 0        /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1        /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2        /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3        /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4         /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
# ...                                   ...
# 1129222                               NaN
# 1129223                               NaN
# 1129224  /eTVp4OyCrbNkKBsKz30Dtc7sVdG.jpg
# 1129225                               NaN
# 1129226                               NaN
#
#                                                    tagline  \
# 0                     Your mind is the scene of the crime.
# 1        Mankind was born on Earth. It was never meant ...
# 2                        Welcome to a world without rules.
# 3                              Enter the world of Pandora.
# 4                                  Some assembly required.
# ...                                                    ...
# 1129222                                                NaN
# 1129223                                                NaN
# 1129224                                                NaN
# 1129225                                                NaN
# 1129226                                                NaN
#
#                                               genres  \
# 0                 Action, Science Fiction, Adventure
# 1                  Adventure, Drama, Science Fiction
# 2                     Drama, Action, Crime, Thriller
# 3        Action, Adventure, Fantasy, Science Fiction
# 4                 Science Fiction, Action, Adventure
# ...                                              ...
# 1129222                                          NaN
# 1129223                                          NaN
# 1129224                                        Drama
# 1129225                                          NaN
# 1129226                                          NaN
#
#                                       production_companies  \
# 0        Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1        Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2        DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3        Dune Entertainment, Lightstorm Entertainment, ...
# 4                                           Marvel Studios
# ...                                                    ...
# 1129222                                                NaN
# 1129223                                                NaN
# 1129224                                                NaN
# 1129225                                                NaN
# 1129226                                                NaN
#
#                              production_countries  \
# 0        United Kingdom, United States of America
# 1        United Kingdom, United States of America
# 2        United Kingdom, United States of America
# 3        United States of America, United Kingdom
# 4                        United States of America
# ...                                           ...
# 1129222                                       NaN
# 1129223                                       NaN
# 1129224                  United States of America
# 1129225                                       NaN
# 1129226                                       NaN
#
#                            spoken_languages  \
# 0        English, French, Japanese, Swahili
# 1                                   English
# 2                         English, Mandarin
# 3                          English, Spanish
# 4                   English, Hindi, Russian
# ...                                     ...
# 1129222                                 NaN
# 1129223                              German
# 1129224                             English
# 1129225                              German
# 1129226                                 NaN
#
#                                                   keywords  \
# 0        rescue, mission, dream, airplane, paris, franc...
# 1        rescue, future, spacecraft, race against time,...
# 2        joker, sadism, chaos, secret identity, crime f...
# 3        future, society, culture clash, space travel, ...
# 4        new york city, superhero, shield, based on com...
# ...                                                    ...
# 1129222                                                NaN
# 1129223                                                NaN
# 1129224                                                NaN
# 1129225                                                NaN
# 1129226                                                NaN
#
#                        normalized_name
# 0                            inception
# 1                         interstellar
# 2                      the dark knight
# 3                               avatar
# 4                         the avengers
# ...                                ...
# 1129222                     love lives
# 1129223  close your eyes to see better
# 1129224              men who dont work
# 1129225    torture in stammheim prison
# 1129226               brownout capital
#
# [1129227 rows x 25 columns]

# %%
df_tmdb['overview']
# Out:
# 0          Cobb, a skilled thief who commits corporate es...
# 1          The adventures of a group of explorers who mak...
# 2          Batman raises the stakes in his war on crime. ...
# 3          In the 22nd century, a paraplegic Marine is di...
# 4          When an unexpected enemy emerges and threatens...
#                                  ...
# 1129222    Filmed over several days in Sheffield, UK, thi...
# 1129223    This video was made in 1986 by residents of Ha...
# 1129224    When an unusual family moves into a house on h...
# 1129225    When a law enforcement officer unravels the ce...
# 1129226    In the outskirts of Palawan, a man hunts for i...
# Name: overview, Length: 1129227, dtype: object

# %%
df_tmdb.columns
# Out:
# Index(['id', 'title', 'vote_average', 'vote_count', 'status', 'release_date',
#        'revenue', 'runtime', 'adult', 'backdrop_path', 'budget', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'tagline', 'genres',
#        'production_companies', 'production_countries', 'spoken_languages',
#        'keywords'],
#       dtype='object')

# %%
commom_movies_cmu_tmdb2.drop(columns=['vote_average', 'vote_count', 'status', 'adult', 'backdrop_path', 'homepage', 
                                     'imdb_id', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 
                                      'tagline', 'genres', 'production_companies', 'production_countries', 'spoken_languages'])
# Out:
#         Wikipedia_ID Freebase_ID  \
# 0             975900   /m/03vyhn
# 1            3196793   /m/08yl5d
# 2            9363483  /m/0285_cd
# 3             261236   /m/01mrr1
# 4           13696889  /m/03cfc81
# ...              ...         ...
# 218023      31353375  /m/0gkz70w
# 218024      26482675  /m/0bbwngb
# 218044      35228177  /m/0j7hxnt
# 218045      34980460  /m/0g4pl34
# 218047       9971909  /m/02pygw1
#
#                                                Movie_name Release_date  \
# 0                                          Ghosts of Mars   2001-08-24
# 1       Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 2                                        White Of The Eye         1987
# 3                                       A Woman in Flames         1983
# 4                                           The Gangsters   1913-05-29
# ...                                                   ...          ...
# 218023                               The Luck of the Navy   1927-11-22
# 218024                                     Eşrefpaşalılar   2010-03-05
# 218044                           Mermaids: The Body Found   2011-03-19
# 218045                                            Knuckle   2011-01-21
# 218047                                  Another Nice Mess   1972-09-22
#
#         Box_office  Runtime  \
# 0       14010832.0     98.0
# 1              NaN     95.0
# 2              NaN    110.0
# 3              NaN    106.0
# 4              NaN     35.0
# ...            ...      ...
# 218023         NaN    110.0
# 218024   1847671.0      NaN
# 218044         NaN    120.0
# 218045         NaN     96.0
# 218047         NaN     66.0
#
#                                           Movie_languages  \
# 0                      {"/m/02h40lc": "English Language"}
# 1                      {"/m/02h40lc": "English Language"}
# 2                      {"/m/02h40lc": "English Language"}
# 3                       {"/m/04306rv": "German Language"}
# 4       {"/m/06ppq": "Silent film", "/m/02h40lc": "Eng...
# ...                                                   ...
# 218023                                                 {}
# 218024                                                 {}
# 218044                 {"/m/02h40lc": "English Language"}
# 218045                 {"/m/02h40lc": "English Language"}
# 218047                 {"/m/02h40lc": "English Language"}
#
#                                           Movie_countries  \
# 0               {"/m/09c7w0": "United States of America"}
# 1               {"/m/09c7w0": "United States of America"}
# 2                          {"/m/07ssc": "United Kingdom"}
# 3                                 {"/m/0345h": "Germany"}
# 4               {"/m/09c7w0": "United States of America"}
# ...                                                   ...
# 218023                     {"/m/07ssc": "United Kingdom"}
# 218024                                                 {}
# 218044          {"/m/09c7w0": "United States of America"}
# 218045  {"/m/03rt9": "Ireland", "/m/07ssc": "United Ki...
# 218047          {"/m/09c7w0": "United States of America"}
#
#                                              Movie_genres  \
# 0       {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1       {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2       {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 3                                 {"/m/07s9rl0": "Drama"}
# 4       {"/m/02hmvc": "Short Film", "/m/06ppq": "Silen...
# ...                                                   ...
# 218023  {"/m/01jfsb": "Thriller", "/m/06ppq": "Silent ...
# 218024  {"/m/05p553": "Comedy film", "/m/07s9rl0": "Dr...
# 218044                            {"/m/07s9rl0": "Drama"}
# 218045  {"/m/03bxz7": "Biographical film", "/m/07s9rl0...
# 218047       {"/m/06nbt": "Satire", "/m/01z4y": "Comedy"}
#
#                                           normalized_name      id  \
# 0                                          ghosts of mars   10016
# 1       getting away with murder the jonbenét ramsey m...  784579
# 2                                        white of the eye   33592
# 3                                       a woman in flames   11192
# 4                                           the gangsters  263493
# ...                                                   ...     ...
# 218023                               the luck of the navy  295963
# 218024                                     eşrefpaşalılar   50009
# 218044                            mermaids the body found  117124
# 218045                                            knuckle   71771
# 218047                                  another nice mess  285337
#
#                                                     title release_date  \
# 0                                          Ghosts of Mars   2001-08-24
# 1       Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 2                                        White of the Eye   1987-06-19
# 3                                       A Woman in Flames   1983-05-11
# 4                                           The Gangsters   1913-05-29
# ...                                                   ...          ...
# 218023                               The Luck of the Navy   1927-11-22
# 218024                                     Eşrefpaşalılar   2010-03-05
# 218044                           Mermaids: The Body Found   2011-03-19
# 218045                                            Knuckle   2011-12-09
# 218047                                  Another Nice Mess   1972-08-23
#
#          revenue  runtime    budget  \
# 0       14010832       98  28000000
# 1              0       60         0
# 2              0      111         0
# 3              0      106         0
# 4              0       35         0
# ...          ...      ...       ...
# 218023         0      110         0
# 218024         0      103         0
# 218044         0       82         0
# 218045         0       97         0
# 218047         0       66         0
#
#                                                  keywords
# 0       future, planet mars, anti hero, possession, ho...
# 1                                      colorado, jonbenet
# 2       based on novel or book, gas station, psychopat...
# 3       jealousy, eroticism, gigolo, longing, dominatr...
# 4                         slapstick comedy, keystone kops
# ...                                                   ...
# 218023                                                NaN
# 218024                                                NaN
# 218044            mermaid, mockumentary, fake documentary
# 218045             sports, bare knuckle boxing, fistfight
# 218047                                                NaN
#
# [59359 rows x 17 columns]

# %%
# TO DO 
# 1) Find missing values and correct wrong values using TMdB dataset
# 2) Work with
